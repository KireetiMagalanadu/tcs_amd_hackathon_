# %% [markdown]
# # Model 3 — EEG WaveNet 1D Dilated Causal CNN → Transformer + MSM Pretraining
# **Multimodal Intraoperative Prediction System — Model 3 of 5**
#
# Encodes brain electrical state from raw EEG waveforms (`BIS/EEG1_WAV`, `BIS/EEG2_WAV`) and BIS scalar channels.
# - **Backbone**: WaveNet dilated causal CNN → Transformer encoder
# - **Stage 0**: Masked Segment Modelling (MSM) self-supervised pretraining
# - **Stage 1**: Supervised fine-tuning for IOH (primary) and N/H (secondary) labels
# - **SQI gate**: windows with `BIS/SQI < 70` excluded from loss; EEG embedding zeroed when `SQI < 50`
# - **EEG sample rate**: 128 Hz

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 1. Imports and seed setting
# ─────────────────────────────────────────────────────────────────────────────
from __future__ import annotations
import gc
import logging
import math
import os
import random
import time
from typing import Dict, List, Optional, Tuple

import matplotlib
matplotlib.use("Agg")  # non-interactive backend
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shap
import torch
import torch.nn as nn
import torch.nn.functional as F
from scipy.signal import stft as scipy_stft
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Updated: torch.amp replaces deprecated torch.cuda.amp imports
from torch.amp import GradScaler, autocast

from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
import vitaldb  # VitalDB Python package — live download, in-memory only

# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 2. CONFIG dict — ALL hyperparameters, track names, file paths
#    NOTE: EEG sample rate is 128 Hz (not 500 Hz).
#          All derived sample counts updated accordingly.
# ─────────────────────────────────────────────────────────────────────────────
CONFIG: Dict = {
    # ── Identity ─────────────────────────────────────────────────────────────
    "model_name": "model_3",
    "output_file": "model_3.py",
    "log_file": "model_3.log",

    # ── VitalDB tracks ────────────────────────────────────────────────────────
    # Raw EEG at 128 Hz
    "wav_tracks": ["BIS/EEG1_WAV", "BIS/EEG2_WAV"],
    "wav_interval": 1 / 128,        # seconds per sample → 128 Hz

    # BIS scalar channels at 1 Hz
    "scalar_tracks": [
        "BIS/BIS", "BIS/SQI", "BIS/EMG",
        "BIS/SR", "BIS/SEF", "BIS/TOTPOW",
        "Solar8000/ART_MBP",         # needed for IOH label construction
        "Solar8000/HR",              # needed for N/H label
    ],
    "scalar_interval": 1,           # 1 Hz

    # Clinical metadata params loaded via load_clinical_data()
    "clinical_params": [
    "anestart", "aneend", "opstart", "opend", "ane_type",],

    # ── Case eligibility ──────────────────────────────────────────────────────
    "min_case_duration_sec": 1800,  # 30 minutes minimum
    "min_sqi_coverage": 0.70,       # >= 70 % of case must have SQI >= 70
    "sqi_train_threshold": 70,      # exclude from loss when SQI < 70
    "sqi_zero_threshold": 50,       # zero-out embedding when SQI < 50

    # ── Window / stride ───────────────────────────────────────────────────────
    "history_sec": 1800,            # 30-min history window → 1800 s at 1 Hz
    "stride_sec": 60,               # 1-minute stride between windows
    "max_nan_frac": 0.20,           # discard window if > 20 % NaN in any channel
    "max_fill_gap_sec": 60,         # forward-fill up to 60 s

    # ── IOH label ─────────────────────────────────────────────────────────────
    "ioh_thresholds_mmhg": 65.0,
    "ioh_min_duration_sec": 60,
    "ioh_horizons_sec": [300, 600, 900],   # t+5, t+10, t+15 min

    # ── N/H label ─────────────────────────────────────────────────────────────
    "nh_n_classes": 3,
    "nh_label_smoothing": 0.15,
    "nh_focal_gamma": 2.0,
    "nh_hr_high": 90,               # bpm threshold for nociception excess
    "nh_bis_low": 60,               # BIS threshold for nociception excess
    "nh_bis_high": 65,              # BIS rising threshold for hypnosis excess
    "nh_hr_rise_frac": 0.15,        # 15 % HR rise for hypnosis excess

    # ── Waveform pre-processing ───────────────────────────────────────────────
    "eeg_fs": 128,                  # Hz — BIS EEG waveform sample rate
    "eeg_window_sec": 30,           # raw EEG per 1-Hz output step: 30 s × 128 = 3840 samples
    "eeg_samples_per_step": 3840,   # 30 s × 128 Hz

    # ── STFT spectral features ────────────────────────────────────────────────
    "stft_win_sec": 4,              # 4-s Hann window
    "stft_overlap": 0.5,            # 50 % overlap
    "stft_bands": {                 # Hz bands → band power features
        "delta": (0.5, 4.0),
        "theta": (4.0, 8.0),
        "alpha": (8.0, 13.0),
        "beta":  (13.0, 30.0),
    },

    # ── BSR ───────────────────────────────────────────────────────────────────
    "bsr_window_sec": 63,           # 63-s BSR window (per spec)
    "bsr_amplitude_uv": 5.0,        # amplitude threshold for suppression

    # ── WaveNet CNN ───────────────────────────────────────────────────────────
    "wavenet_dilations": [
        1, 2, 4, 8, 16, 32, 64, 128,
        1, 2, 4, 8, 16, 32, 64, 128,
    ],                              # 16 layers, two cycles of 8
    "wavenet_kernel_size": 3,
    "wavenet_residual_channels": 64,
    "wavenet_skip_channels": 64,
    "wavenet_cnn_out_dim": 64,      # output feature dim after CNN
    "wavenet_n_output_vectors": 256,  # 3840 samples → pooled to 256 vectors
                                      # (reduced from 512 to match 128 Hz input)

    # ── MSM pretraining ───────────────────────────────────────────────────────
    "msm_mask_prob": 0.20,          # 20 % of raw EEG masked
    "msm_mask_span_sec": 0.5,       # random spans of 0.5 s
    "msm_mask_span_samples": 64,    # 0.5 s × 128 Hz = 64 samples
    "msm_epochs": 20,
    "msm_lr": 1e-4,
    "msm_batch_size": 8,            # small batch — raw EEG is large

    # ── Transformer ───────────────────────────────────────────────────────────
    "transformer_d_model": 128,
    "transformer_n_heads": 4,
    "transformer_n_layers": 4,
    "transformer_ffn_dim": 256,
    "transformer_dropout": 0.1,
    "transformer_n_spectral_features": 6,  # FIX: compute_spectral_features returns 6: 4 band powers + SEF95 + BSR

    # ── Supervised training ───────────────────────────────────────────────────
    "sup_epochs": 50,
    "sup_lr": 5e-5,
    "batch_size": 4,               # raw EEG waveforms → large tensors
    "gradient_accumulation_steps": 4,
    "early_stopping_patience": 8,
    "weight_decay": 1e-4,
    "max_grad_norm": 1.0,

    # ── Embedding ─────────────────────────────────────────────────────────────
    "embedding_dim": 128,          # final output embedding dimension

    # ── EEG amplitude clipping (µV) for numerical stability ──────────────────
    "eeg_clip_uv": 500.0,             # clip raw EEG to ±500 µV before model input

    # ── Data split ────────────────────────────────────────────────────────────
    "val_frac": 0.10,
    "test_frac": 0.10,
    "seed": 42,

    # ── Output files ──────────────────────────────────────────────────────────
    "shap_output": "shap_model_3.png",
    "pred_output": "prediction_model_3.png",
    "checkpoint_msm": "ckpt_model_3_msm.pt",
    "checkpoint_sup": "ckpt_model_3_sup.pt",
}

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 3. Logging setup
# ─────────────────────────────────────────────────────────────────────────────
def setup_logging(log_file: str) -> logging.Logger:
    """Configure root logger with both file and console handlers.

    Parameters
    ----------
    log_file : str
        Path to the log file.

    Returns
    -------
    logging.Logger
        Configured logger.
    """
    fmt = logging.Formatter(
        "%(asctime)s | %(levelname)-8s | %(name)s | %(message)s",
        datefmt="%Y-%m-%d %H:%M:%S",
    )
    logger = logging.getLogger("model_3")
    logger.setLevel(logging.DEBUG)

    # Console handler
    ch = logging.StreamHandler()
    ch.setLevel(logging.INFO)
    ch.setFormatter(fmt)
    logger.addHandler(ch)

    # File handler
    fh = logging.FileHandler(log_file, mode="w")
    fh.setLevel(logging.DEBUG)
    fh.setFormatter(fmt)
    logger.addHandler(fh)

    return logger

log = setup_logging(CONFIG["log_file"])

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 4a. Clinical metadata loader
# ─────────────────────────────────────────────────────────────────────────────
def load_clinical_metadata(config: Dict) -> pd.DataFrame:
    """Load per-case clinical metadata from VitalDB.

    Parameters
    ----------
    config : Dict
        Global CONFIG dictionary (uses 'clinical_params').

    Returns
    -------
    pd.DataFrame
        One row per case with clinical columns.
    """
    log.info("Loading clinical metadata …")
    caseids = list(range(1, 6389))
    try:
        # Load clinical data CSV
        df = pd.read_csv("clinical_data.csv")
        
        # Keep only required cases
        df = df[df["caseid"].isin(caseids)]
        
        # Keep only requested columns
        cols = ["caseid"] + config["clinical_params"]
        df = df[cols]
    except Exception as exc:
        log.error(f"load_clinical_data failed: {exc}")
        raise
    log.info(f"Clinical metadata loaded: {len(df)} rows, {list(df.columns)}")
    return df

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 4b. Waveform data loader (EEG-only tracks)
#     Loads EEG at 128 Hz and BIS scalars at 1 Hz.
# ─────────────────────────────────────────────────────────────────────────────
def load_waveform_data(
    caseids: List[int],
    config: Dict,
) -> Tuple[Dict[int, np.ndarray], Dict[int, np.ndarray]]:
    """Load raw EEG waveforms (128 Hz) and BIS scalars (1 Hz) for valid cases.

    Parameters
    ----------
    caseids : List[int]
        List of case IDs to attempt loading.
    config : Dict
        Global CONFIG dictionary.

    Returns
    -------
    wav_data : Dict[int, np.ndarray]
        Mapping caseid → float32 array (T_wav, 2) at 128 Hz.
    scalar_data : Dict[int, np.ndarray]
        Mapping caseid → float32 array (T_1hz, n_scalar_tracks) at 1 Hz.
    """
    wav_data: Dict[int, np.ndarray] = {}
    scalar_data: Dict[int, np.ndarray] = {}

    wav_tracks    = config["wav_tracks"]          # BIS/EEG1_WAV, BIS/EEG2_WAV
    scalar_tracks = config["scalar_tracks"]       # BIS/BIS, SQI, …, ART_MBP, HR
    wav_interval    = config["wav_interval"]      # 1/128
    scalar_interval = config["scalar_interval"]   # 1

    for caseid in tqdm(caseids, desc="Loading EEG waveforms"):

        # ── Load 128 Hz waveforms ─────────────────────────────────────────────
        try:
            arr_wav = vitaldb.load_case(
                caseid=caseid,
                track_names=wav_tracks,
                interval=wav_interval,
            )
        except Exception as exc:
            log.warning(f"caseid {caseid}: wav load failed — {exc}")
            arr_wav = None

        if arr_wav is None:
            log.warning(f"caseid {caseid}: wav returned None, skipping")
            continue

        # ── Load 1 Hz scalars ─────────────────────────────────────────────────
        try:
            arr_scalar = vitaldb.load_case(
                caseid=caseid,
                track_names=scalar_tracks,
                interval=scalar_interval,
            )
        except Exception as exc:
            log.warning(f"caseid {caseid}: scalar load failed — {exc}")
            del arr_wav
            gc.collect()
            continue

        if arr_scalar is None:
            log.warning(f"caseid {caseid}: scalar returned None, skipping")
            del arr_wav
            gc.collect()
            continue

        wav_data[caseid]    = arr_wav.astype(np.float32)
        scalar_data[caseid] = arr_scalar.astype(np.float32)

    log.info(
        f"Loaded waveform data for {len(wav_data)} cases "
        f"({len(caseids) - len(wav_data)} skipped)"
    )
    return wav_data, scalar_data

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Utility: max consecutive run of 1s in a binary array
# ─────────────────────────────────────────────────────────────────────────────
def max_run_length(arr: np.ndarray) -> int:
    """Return the maximum number of consecutive 1s in a binary array.

    Parameters
    ----------
    arr : np.ndarray
        1D binary integer array.

    Returns
    -------
    int
        Maximum run length of consecutive 1s.
    """
    if arr.sum() == 0:
        return 0
    max_run = 0
    current = 0
    for v in arr:
        if v:
            current += 1
            max_run = max(max_run, current)
        else:
            current = 0
    return max_run

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 4c. IOH label construction
# ─────────────────────────────────────────────────────────────────────────────
def build_ioh_labels(
    map_series: np.ndarray,
    config: Dict,
) -> Dict[str, np.ndarray]:
    """Build binary IOH labels at each prediction horizon.

    A positive label is assigned when MAP drops below threshold and stays below
    for at least min_duration_sec within the prediction window.

    Parameters
    ----------
    map_series : np.ndarray
        1D float array of MAP values at 1 Hz.
    config : Dict
        Global CONFIG dictionary.

    Returns
    -------
    Dict[str, np.ndarray]
        Keys: 'ioh_5', 'ioh_10', 'ioh_15'; values: binary float32 1D arrays.
    """
    threshold = config["ioh_thresholds_mmhg"]
    min_dur   = config["ioh_min_duration_sec"]
    labels: Dict[str, np.ndarray] = {}

    for horizon_sec in config["ioh_horizons_sec"]:
        n   = len(map_series)
        lbl = np.zeros(n, dtype=np.float32)
        for t in range(n - horizon_sec):
            window = map_series[t: t + horizon_sec]
            below  = (window < threshold).astype(int)
            run    = max_run_length(below)
            if run >= min_dur:
                lbl[t] = 1.0
        key = f"ioh_{horizon_sec // 60}"  # e.g. 'ioh_5'
        labels[key] = lbl

    return labels

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 4d. N/H label construction (noisy supervision)
# ─────────────────────────────────────────────────────────────────────────────
def build_nh_labels(
    bis_series: np.ndarray,
    hr_series: np.ndarray,
    config: Dict,
) -> np.ndarray:
    """Build 3-class N/H labels from heuristic rules (noisy supervision).

    Classes
    -------
    0 : Adequate balance
    1 : Nociception excess  — concurrent HR > 90 bpm AND BIS < 60
    2 : Hypnosis excess     — rising BIS > 65 AND HR rise > 15 % over 5 min

    Parameters
    ----------
    bis_series : np.ndarray
        1D BIS values at 1 Hz.
    hr_series : np.ndarray
        1D HR values at 1 Hz.
    config : Dict
        Global CONFIG dict.

    Returns
    -------
    np.ndarray
        Integer array of class indices (0, 1, 2), shape (T,).
    """
    n      = len(bis_series)
    labels = np.zeros(n, dtype=np.int64)

    hr_high      = config["nh_hr_high"]
    bis_low      = config["nh_bis_low"]
    bis_high     = config["nh_bis_high"]
    hr_rise_frac = config["nh_hr_rise_frac"]
    lookback     = 300  # 5-min lookback for HR rise calculation

    for t in range(lookback, n):
        bis_t = bis_series[t]
        hr_t  = hr_series[t]
        if np.isnan(bis_t) or np.isnan(hr_t):
            continue

        # Nociception excess: high HR AND low BIS simultaneously
        if hr_t > hr_high and bis_t < bis_low:
            labels[t] = 1
            continue

        # Hypnosis excess: BIS rising above threshold AND HR increased ≥ 15 %
        hr_past = hr_series[t - lookback: t]
        if not np.all(np.isnan(hr_past)):
            hr_mean_past = float(np.nanmean(hr_past))
            if hr_mean_past > 0:
                hr_rise = (hr_t - hr_mean_past) / hr_mean_past
                if bis_t > bis_high and hr_rise > hr_rise_frac:
                    labels[t] = 2

    return labels

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 4e. Emergence timing label (stored but not primary for Model 3)
# ─────────────────────────────────────────────────────────────────────────────
def build_et_label(row: pd.Series) -> float:
    """Return emergence time (aneend - opend) in seconds, or -1 if invalid.

    Parameters
    ----------
    row : pd.Series
        A single row from the clinical metadata DataFrame.

    Returns
    -------
    float
        Emergence duration in seconds, or -1.0 if outside valid range.
    """
    try:
        et = float(row["aneend"]) - float(row["opend"])
    except (TypeError, ValueError):
        return -1.0
    # Keep only 0 < ET < 3600 s (per spec)
    if et <= 0 or et >= 3600:
        return -1.0
    return float(et)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 5a. Forward-fill / backward-fill NaN gaps
# ─────────────────────────────────────────────────────────────────────────────
def forward_fill_gaps(arr: np.ndarray, max_gap_sec: int) -> np.ndarray:
    """Fill NaN gaps up to max_gap_sec using linear interpolation first,
    then forward-fill, then backward-fill for any remaining NaNs at edges.

    Parameters
    ----------
    arr : np.ndarray
        2D float array (T, F). Operates column-wise.
    max_gap_sec : int
        Maximum consecutive NaN samples to fill (1 Hz → 1 sample per second).
        Gaps longer than this are left as NaN for window discard.

    Returns
    -------
    np.ndarray
        Filled array, same shape as input.
    """
    out = arr.copy()
    T, F = out.shape

    for f in range(F):
        col     = out[:, f]
        nan_idx = np.where(np.isnan(col))[0]
        if len(nan_idx) == 0:
            continue

        gaps = np.split(nan_idx, np.where(np.diff(nan_idx) != 1)[0] + 1)

        for gap in gaps:
            gap_len = len(gap)
            start   = gap[0]
            end     = gap[-1]

            if gap_len > max_gap_sec:
                continue  # too long — leave as NaN for window discard

            has_left  = start > 0 and not np.isnan(col[start - 1])
            has_right = end < T - 1 and not np.isnan(col[end + 1])

            if has_left and has_right:
                # Linear interpolation between the two known boundary values
                left_val  = col[start - 1]
                right_val = col[end + 1]
                col[gap]  = np.linspace(left_val, right_val, gap_len + 2)[1:-1]
            elif has_left:
                # No right anchor — forward-fill from left
                col[gap] = col[start - 1]
            elif has_right:
                # No left anchor (leading NaNs) — backward-fill from right
                col[gap] = col[end + 1]
            # else: isolated NaN island with no valid neighbours — leave as NaN

        out[:, f] = col

    return out

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 5b. Outlier removal (physiological clipping for scalar channels)
# ─────────────────────────────────────────────────────────────────────────────
def remove_outliers(arr: np.ndarray, method: str = "physiological") -> np.ndarray:
    """Clip physiologically implausible values in scalar channels.

    Out-of-range values are set to NaN (handled by forward-fill or window discard).

    Parameters
    ----------
    arr : np.ndarray
        2D float array (T, F) — must correspond to CONFIG['scalar_tracks'] order.
    method : str
        'physiological' (default) or 'iqr'.

    Returns
    -------
    np.ndarray
        Clipped array, same shape.
    """
    out = arr.copy()

    if method == "physiological":
        # Column order matches CONFIG['scalar_tracks']:
        # 0:BIS/BIS  1:BIS/SQI  2:BIS/EMG  3:BIS/SR  4:BIS/SEF  5:BIS/TOTPOW
        # 6:Solar8000/ART_MBP  7:Solar8000/HR
        bounds = [
            (0, 100),      # BIS
            (0, 100),      # SQI
            (0, 100),      # EMG
            (0, 100),      # SR (burst suppression ratio 0–100 %)
            (0, 50),       # SEF (spectral edge frequency Hz)
            (0, 200),      # TOTPOW (dB arbitrary units)
            (20, 200),     # MAP mmHg
            (20, 250),     # HR bpm
        ]
        n_cols = min(out.shape[1], len(bounds))
        for col_idx in range(n_cols):
            lo, hi = bounds[col_idx]
            col = out[:, col_idx]
            col = np.where((col < lo) | (col > hi), np.nan, col)
            out[:, col_idx] = col

    elif method == "iqr":
        for col_idx in range(out.shape[1]):
            col   = out[:, col_idx]
            valid = col[~np.isnan(col)]
            if len(valid) < 4:
                continue
            q1, q3 = np.percentile(valid, [25, 75])
            iqr     = q3 - q1
            lo, hi  = q1 - 3.0 * iqr, q3 + 3.0 * iqr
            out[:, col_idx] = np.where((col < lo) | (col > hi), np.nan, col)

    return out

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 5c. Spectral feature computation (EEG-specific, 128 Hz input)
# ─────────────────────────────────────────────────────────────────────────────
def compute_spectral_features(
    eeg_window: np.ndarray,
    config: Dict,
) -> np.ndarray:
    """Compute band powers, SEF95, and BSR from a raw EEG segment.

    Operates on 128 Hz EEG. The STFT window is 4 s (512 samples at 128 Hz).
    Maximum resolvable frequency is 64 Hz (Nyquist), which comfortably covers
    all clinical EEG bands (delta–beta).

    Parameters
    ----------
    eeg_window : np.ndarray
        1D float array (N_samples,) at 128 Hz.
    config : Dict
        Global CONFIG dict.

    Returns
    -------
    np.ndarray
        1D feature vector: [delta_power, theta_power, alpha_power, beta_power,
                             sef95, bsr] — shape (6,).
    """
    fs       = config["eeg_fs"]          # 128 Hz
    win_sec  = config["stft_win_sec"]    # 4 s → 512 samples
    overlap  = config["stft_overlap"]   # 50 %
    bands    = config["stft_bands"]
    bsr_win  = config["bsr_window_sec"] # 63 s
    bsr_amp  = config["bsr_amplitude_uv"]

    nperseg  = int(win_sec * fs)                          # 512 samples at 128 Hz
    # FIX: clamp nperseg to actual signal length so noverlap < nperseg always holds
    nperseg  = min(nperseg, len(eeg_window))
    nperseg  = max(nperseg, 4)                            # must be >= 4
    noverlap = int(nperseg * overlap)                     # 50% of actual nperseg

    try:
        freqs, _, Zxx = scipy_stft(
            eeg_window, fs=fs,
            window="hann", nperseg=nperseg, noverlap=noverlap,
        )
        power      = np.abs(Zxx) ** 2         # (n_freqs, n_frames)
        mean_power = power.mean(axis=1)       # average over time frames

        band_powers = []
        for band_name, (flo, fhi) in bands.items():
            mask = (freqs >= flo) & (freqs < fhi)
            bp   = mean_power[mask].sum() if mask.any() else 0.0
            band_powers.append(float(np.log1p(bp)))  # FIX: log1p prevents fp16 overflow

        # SEF95: frequency below which 95 % of total power resides
        total_power = mean_power.sum()
        if total_power > 0:
            cum_power = np.cumsum(mean_power)
            sef95_idx = np.searchsorted(cum_power, 0.95 * total_power)
            sef95     = float(freqs[min(sef95_idx, len(freqs) - 1)])
        else:
            sef95 = 0.0

    except Exception as exc:
        log.debug(f"STFT failed: {exc}")
        band_powers = [0.0, 0.0, 0.0, 0.0]
        sef95       = 0.0

    # BSR: fraction of 63-s window with amplitude < bsr_amp µV
    bsr_samples = int(bsr_win * fs)   # 63 × 128 = 8064 samples
    segment     = eeg_window[-bsr_samples:] if len(eeg_window) >= bsr_samples else eeg_window
    bsr         = float((np.abs(segment) < bsr_amp).mean()) if len(segment) > 0 else 0.0

    return np.array(band_powers + [sef95, bsr], dtype=np.float32)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 6. Window generation
#    eeg_samples_per_step = 3840 (30 s × 128 Hz)
# ─────────────────────────────────────────────────────────────────────────────
def generate_windows(
    wav_data: Dict[int, np.ndarray],
    scalar_data: Dict[int, np.ndarray],
    clinical_df: pd.DataFrame,
    config: Dict,
) -> List[Dict]:
    """Extract labelled sliding windows from all valid cases.

    Each window contains:
    - Raw EEG waveform chunk (3840, 2) for the 30-s preceding each 1-Hz step
    - Scalar features for the 1800-s history
    - Pre-computed spectral features per 1-Hz step
    - IOH, N/H, ET labels

    Parameters
    ----------
    wav_data : Dict[int, np.ndarray]
        Waveform arrays at 128 Hz.
    scalar_data : Dict[int, np.ndarray]
        Scalar arrays at 1 Hz.
    clinical_df : pd.DataFrame
        Clinical metadata.
    config : Dict
        Global CONFIG dict.

    Returns
    -------
    List[Dict]
    """
    windows: List[Dict] = []

    history_sec          = config["history_sec"]
    stride_sec           = config["stride_sec"]
    max_nan_frac         = config["max_nan_frac"]
    eeg_samples_per_step = config["eeg_samples_per_step"]  # 3840
    eeg_fs               = config["eeg_fs"]                # 128

    sqi_col_idx = 1   # BIS/SQI
    map_col_idx = 6   # Solar8000/ART_MBP
    hr_col_idx  = 7   # Solar8000/HR
    bis_col_idx = 0   # BIS/BIS

    clinical_df = clinical_df.set_index("caseid")

    for caseid, arr_scalar in tqdm(scalar_data.items(), desc="Generating windows"):
        arr_wav = wav_data.get(caseid)
        if arr_wav is None:
            log.warning(f"caseid {caseid}: no waveform data, skipping window generation")
            continue

        if caseid not in clinical_df.index:
            log.warning(f"caseid {caseid}: missing clinical metadata, skipping")
            del arr_wav; gc.collect(); continue

        row      = clinical_df.loc[caseid]
        T_scalar = arr_scalar.shape[0]

        if T_scalar < config["min_case_duration_sec"]:
            log.debug(f"caseid {caseid}: too short ({T_scalar}s), skipping")
            del arr_wav; gc.collect(); continue

        # ── SQI coverage check ────────────────────────────────────────────────
        sqi_col  = arr_scalar[:, sqi_col_idx]
        valid_sqi = ~np.isnan(sqi_col)
        if valid_sqi.sum() > 0:
            sqi_coverage = (sqi_col[valid_sqi] >= config["sqi_train_threshold"]).mean()
        else:
            sqi_coverage = 0.0

        if sqi_coverage < config["min_sqi_coverage"]:
            log.debug(f"caseid {caseid}: SQI coverage {sqi_coverage:.2f} < threshold, skipping")
            del arr_wav; gc.collect(); continue

        # ── Pre-process scalar array ──────────────────────────────────────────
        arr_scalar = remove_outliers(arr_scalar, method="physiological")
        arr_scalar = forward_fill_gaps(arr_scalar, max_gap_sec=config["max_fill_gap_sec"])

        # ── Build labels ──────────────────────────────────────────────────────
        map_series = arr_scalar[:, map_col_idx]
        ioh_labels = build_ioh_labels(map_series, config)
        bis_series = arr_scalar[:, bis_col_idx]
        hr_series  = arr_scalar[:, hr_col_idx]
        nh_labels  = build_nh_labels(bis_series, hr_series, config)
        et_val     = build_et_label(row)

        has_ioh_positive = any(lbl.sum() > 0 for lbl in ioh_labels.values())
        has_ioh_negative = any((1 - lbl).sum() > 0 for lbl in ioh_labels.values())
        if not (has_ioh_positive or has_ioh_negative):
            log.debug(f"caseid {caseid}: no valid IOH labels, skipping")
            del arr_wav; gc.collect(); continue

        # ── Spectral features per 1-Hz timestep ──────────────────────────────
        # Use the preceding 30 s of EEG1 (3840 samples at 128 Hz).
        eeg_ch0         = arr_wav[:, 0]  # EEG1_WAV channel
        n_steps         = T_scalar
        spectral_features = np.zeros((n_steps, 6), dtype=np.float32)

        for t in range(n_steps):
            wav_t_end   = int((t + 1) * eeg_fs)   # end sample at 128 Hz
            wav_t_start = max(0, wav_t_end - eeg_samples_per_step)
            if wav_t_end > len(eeg_ch0):
                break
            seg = eeg_ch0[wav_t_start:wav_t_end]
            spectral_features[t] = compute_spectral_features(seg, config)

        # ── Sliding window extraction ─────────────────────────────────────────
        case_windows_before = len(windows)

        for t_end in range(history_sec, T_scalar, stride_sec):
            t_start    = t_end - history_sec
            win_scalar = arr_scalar[t_start:t_end, :]

            # Discard window if any channel exceeds NaN threshold
            discard = any(
                np.isnan(win_scalar[:, f_idx]).mean() > max_nan_frac
                for f_idx in range(win_scalar.shape[1])
            )
            if discard:
                continue

            win_scalar = np.nan_to_num(win_scalar, nan=0.0)

            # Raw EEG for the last 30 s: shape (3840, 2)
            wav_end_sample   = int(t_end * eeg_fs)
            wav_start_sample = max(0, wav_end_sample - eeg_samples_per_step)
            if wav_end_sample > arr_wav.shape[0]:
                continue
            win_wav = arr_wav[wav_start_sample:wav_end_sample, :]
            if win_wav.shape[0] < eeg_samples_per_step:
                continue
            # FIX: replace NaN in EEG with 0 and clip to ±500 µV to prevent NaN loss
            win_wav = np.nan_to_num(win_wav, nan=0.0)
            win_wav = np.clip(win_wav, -500.0, 500.0)

            win_spectral = spectral_features[t_start:t_end, :]   # (1800, 6)

            # SQI gate
            sqi_at_end       = arr_scalar[t_end - 1, sqi_col_idx]
            modality_present = not np.isnan(sqi_at_end)

            sqi_win  = arr_scalar[t_start:t_end, sqi_col_idx]
            sqi_mask = (
                ~np.isnan(sqi_win) & (sqi_win >= config["sqi_train_threshold"])
            ).astype(np.float32)

            # Labels at prediction point t_end
            label_ioh_5  = float(ioh_labels["ioh_5"][t_end])  if t_end < len(ioh_labels["ioh_5"])  else 0.0
            label_ioh_10 = float(ioh_labels["ioh_10"][t_end]) if t_end < len(ioh_labels["ioh_10"]) else 0.0
            label_ioh_15 = float(ioh_labels["ioh_15"][t_end]) if t_end < len(ioh_labels["ioh_15"]) else 0.0
            label_nh     = int(nh_labels[t_end]) if t_end < len(nh_labels) else 0

            windows.append({
                "caseid":           caseid,
                "window_start":     t_start,
                "win_scalar":       win_scalar.astype(np.float32),      # (1800, 8)
                "win_wav":          win_wav.astype(np.float32),          # (3840, 2)
                "win_spectral":     win_spectral.astype(np.float32),    # (1800, 6)
                "sqi_mask":         sqi_mask,                            # (1800,)
                "label_ioh_5":      label_ioh_5,
                "label_ioh_10":     label_ioh_10,
                "label_ioh_15":     label_ioh_15,
                "label_nh":         label_nh,
                "label_et":         et_val,
                "modality_present": modality_present,
            })

        case_n_windows = len(windows) - case_windows_before
        log.debug(f"caseid {caseid}: {case_n_windows} windows generated")

        del arr_wav
        del wav_data[caseid]
        gc.collect()

    log.info(f"Total windows generated: {len(windows)}")
    return windows

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 7. Scaler fitting and application
# ─────────────────────────────────────────────────────────────────────────────
def fit_scalers(
    train_windows: List[Dict],
) -> Tuple[StandardScaler, StandardScaler, np.ndarray, np.ndarray]:
    """Fit StandardScalers on training data only.

    FIX: also computes per-channel EEG mean/std for z-score normalisation
    of raw waveforms, preventing fp16 overflow in AMP.

    Parameters
    ----------
    train_windows : List[Dict]

    Returns
    -------
    scaler_scalar   : StandardScaler
    scaler_spectral : StandardScaler
    eeg_mean        : np.ndarray  shape (2,)
    eeg_std         : np.ndarray  shape (2,)
    """
    scalar_stack = np.concatenate(
        [w["win_scalar"].reshape(-1, w["win_scalar"].shape[-1]) for w in train_windows], axis=0
    )
    spectral_stack = np.concatenate(
        [w["win_spectral"].reshape(-1, w["win_spectral"].shape[-1]) for w in train_windows], axis=0
    )
    scaler_scalar   = StandardScaler().fit(scalar_stack)
    scaler_spectral = StandardScaler().fit(spectral_stack)

    # FIX: compute EEG waveform statistics for z-score normalisation
    all_wav = np.concatenate(
        [w["win_wav"].reshape(-1, w["win_wav"].shape[-1]) for w in train_windows], axis=0
    )
    eeg_mean = all_wav.mean(axis=0)                       # (2,)
    eeg_std  = all_wav.std(axis=0).clip(min=1e-6)         # (2,)  avoid div-by-zero
    log.info("Scalers fitted on training data.")
    return scaler_scalar, scaler_spectral, eeg_mean, eeg_std


def apply_scalers(
    windows: List[Dict],
    scaler_scalar: StandardScaler,
    scaler_spectral: StandardScaler,
    eeg_mean: np.ndarray,
    eeg_std:  np.ndarray,
) -> List[Dict]:
    """Apply pre-fitted scalers to a list of window dicts in-place.

    FIX: also z-score normalises raw EEG waveforms using training statistics.

    Parameters
    ----------
    windows         : List[Dict]
    scaler_scalar   : StandardScaler
    scaler_spectral : StandardScaler
    eeg_mean        : np.ndarray  shape (2,)
    eeg_std         : np.ndarray  shape (2,)

    Returns
    -------
    List[Dict]
    """
    for w in windows:
        T,  F  = w["win_scalar"].shape
        T2, F2 = w["win_spectral"].shape
        w["win_scalar"] = (
            scaler_scalar.transform(w["win_scalar"].reshape(-1, F))
            .reshape(T, F).astype(np.float32)
        )
        w["win_spectral"] = (
            scaler_spectral.transform(w["win_spectral"].reshape(-1, F2))
            .reshape(T2, F2).astype(np.float32)
        )
        # FIX: normalise raw EEG to zero mean unit variance (per channel)
        w["win_wav"] = ((w["win_wav"] - eeg_mean) / eeg_std).astype(np.float32)
    return windows

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 8. Train / Val / Test split (patient-level)
# ─────────────────────────────────────────────────────────────────────────────
def split_cases(
    all_caseids: List[int],
    val_frac: float = 0.10,
    test_frac: float = 0.10,
    seed: int = 42,
) -> Tuple[List[int], List[int], List[int]]:
    """Patient-level split — never split one patient across sets.

    Returns
    -------
    Tuple[List[int], List[int], List[int]]
        (train_caseids, val_caseids, test_caseids)
    """
    train_val, test = train_test_split(all_caseids, test_size=test_frac, random_state=seed)
    val_size        = val_frac / (1.0 - test_frac)
    train, val      = train_test_split(train_val, test_size=val_size, random_state=seed)
    log.info(f"Split: train={len(train)}, val={len(val)}, test={len(test)} cases")
    return train, val, test

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 9. EEGDataset — PyTorch Dataset
# ─────────────────────────────────────────────────────────────────────────────
class EEGDataset(Dataset):
    """PyTorch Dataset for Model 3 EEG windows.

    Parameters
    ----------
    windows : List[Dict]
        Pre-processed window dicts.
    """

    def __init__(self, windows: List[Dict]) -> None:
        self.windows = windows

    def __len__(self) -> int:
        return len(self.windows)

    def __getitem__(self, idx: int) -> Dict:
        """Return tensors for one window.

        Returns
        -------
        Dict with keys:
            x                : FloatTensor (T=1800, n_scalar+n_spectral=14)
            wav              : FloatTensor (3840, 2)  — raw EEG at 128 Hz
            sqi_flag         : FloatTensor (T,)       — 1.0 where SQI >= 70
            label_ioh_5/10/15: FloatTensor scalar
            label_nh         : LongTensor scalar class index (0/1/2)
            label_et         : FloatTensor scalar (-1 if unavailable)
            caseid           : int
            window_start     : int
            modality_present : BoolTensor scalar
        """
        w = self.windows[idx]
        # Concatenate scalar (8) and spectral (6) features → (1800, 14)
        x = np.concatenate([w["win_scalar"], w["win_spectral"]], axis=-1)
        return {
            "x":                torch.FloatTensor(x),
            "wav":              torch.FloatTensor(w["win_wav"]),
            "sqi_flag":         torch.FloatTensor(w["sqi_mask"]),
            "label_ioh_5":      torch.FloatTensor([w["label_ioh_5"]]),
            "label_ioh_10":     torch.FloatTensor([w["label_ioh_10"]]),
            "label_ioh_15":     torch.FloatTensor([w["label_ioh_15"]]),
            "label_nh":         torch.LongTensor([w["label_nh"]]),
            "label_et":         torch.FloatTensor([w["label_et"]]),
            "caseid":           w["caseid"],
            "window_start":     w["window_start"],
            "modality_present": torch.BoolTensor([w["modality_present"]]),
        }

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 10. DataLoaders
# ─────────────────────────────────────────────────────────────────────────────
def build_dataloaders(
    train_ds: EEGDataset,
    val_ds:   EEGDataset,
    test_ds:  EEGDataset,
    config:   Dict,
) -> Tuple[DataLoader, DataLoader, DataLoader]:
    """Build train / val / test DataLoaders."""
    bs = config["batch_size"]
    # num_workers=0 — raw EEG tensors are large; multiprocessing adds overhead
    train_loader = DataLoader(train_ds, batch_size=bs, shuffle=True,
                              num_workers=0, pin_memory=True, drop_last=True)
    val_loader   = DataLoader(val_ds,   batch_size=bs, shuffle=False,
                              num_workers=0, pin_memory=True)
    test_loader  = DataLoader(test_ds,  batch_size=bs, shuffle=False,
                              num_workers=0, pin_memory=True)
    log.info(
        f"DataLoaders: train={len(train_loader)} batches, "
        f"val={len(val_loader)}, test={len(test_loader)}"
    )
    return train_loader, val_loader, test_loader

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 11. Model architecture
# ─────────────────────────────────────────────────────────────────────────────

class CausalConv1d(nn.Module):
    """1D causal convolution: left-pads so output[t] depends only on input[<=t]."""

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        dilation: int = 1,
    ) -> None:
        super().__init__()
        self.padding = (kernel_size - 1) * dilation
        self.conv = nn.Conv1d(
            in_channels, out_channels,
            kernel_size=kernel_size, dilation=dilation, padding=0,
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.conv(F.pad(x, (self.padding, 0)))


class WaveNetLayer(nn.Module):
    """Single WaveNet residual layer: dilated causal conv + gated activation + skip."""

    def __init__(
        self,
        residual_channels: int,
        skip_channels: int,
        kernel_size: int = 3,
        dilation: int = 1,
    ) -> None:
        super().__init__()
        self.causal_conv = CausalConv1d(
            residual_channels, 2 * residual_channels,
            kernel_size=kernel_size, dilation=dilation,
        )
        self.res_conv  = nn.Conv1d(residual_channels, residual_channels, kernel_size=1)
        self.skip_conv = nn.Conv1d(residual_channels, skip_channels,     kernel_size=1)

    def forward(self, x: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:
        h = self.causal_conv(x)
        C = h.size(1) // 2
        h = torch.tanh(h[:, :C, :]) * torch.sigmoid(h[:, C:, :])
        skip = self.skip_conv(h)
        res  = self.res_conv(h) + x
        return res, skip


class WaveNetEncoder(nn.Module):
    """16-layer WaveNet dilated causal CNN.

    Compresses (B, 2, 3840) raw EEG (128 Hz) to (B, skip_channels, n_output_vectors)
    via adaptive average pooling.
    """

    def __init__(
        self,
        n_input_channels: int = 2,
        residual_channels: int = 64,
        skip_channels: int = 64,
        kernel_size: int = 3,
        dilations: Optional[List[int]] = None,
        n_output_vectors: int = 256,
    ) -> None:
        super().__init__()
        if dilations is None:
            dilations = [1, 2, 4, 8, 16, 32, 64, 128, 1, 2, 4, 8, 16, 32, 64, 128]

        self.input_proj = nn.Conv1d(n_input_channels, residual_channels, kernel_size=1)
        self.layers = nn.ModuleList([
            WaveNetLayer(residual_channels, skip_channels, kernel_size, d)
            for d in dilations
        ])
        self.post_skip = nn.Sequential(
            nn.ReLU(),
            nn.Conv1d(skip_channels, skip_channels, kernel_size=1),
            nn.ReLU(),
        )
        self.adaptive_pool = nn.AdaptiveAvgPool1d(n_output_vectors)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Parameters
        ----------
        x : Tensor (B, 2, 3840)

        Returns
        -------
        Tensor (B, skip_channels, n_output_vectors)
        """
        h        = self.input_proj(x)
        skip_sum = None
        for layer in self.layers:
            h, skip  = layer(h)
            skip_sum = skip if skip_sum is None else skip_sum + skip
        out = self.post_skip(skip_sum)
        out = self.adaptive_pool(out)
        return out

# %%
class MSMDecoder(nn.Module):
    """Decoder head for Masked Segment Modelling pretraining.

    Reconstructs masked raw EEG segments (128 Hz) from CNN feature maps.
    """

    def __init__(
        self,
        cnn_out_dim: int,
        n_output_samples: int = 3840,   # 30 s × 128 Hz
        n_eeg_channels: int = 2,
    ) -> None:
        super().__init__()
        self.n_output_samples = n_output_samples
        self.n_eeg_channels   = n_eeg_channels

        # Upsample feature map back to raw waveform length
        self.upsample = nn.Sequential(
            nn.ConvTranspose1d(cnn_out_dim, 32, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose1d(32, 16, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose1d(16, n_eeg_channels, kernel_size=4, stride=2, padding=1),
        )
        self.adaptive_upsample = nn.AdaptiveAvgPool1d(n_output_samples)

    def forward(self, z: torch.Tensor) -> torch.Tensor:
        """
        Parameters
        ----------
        z : Tensor (B, cnn_out_dim, n_output_vectors)

        Returns
        -------
        Tensor (B, n_eeg_channels, n_output_samples)  e.g. (B, 2, 3840)
        """
        x = self.upsample(z)
        x = self.adaptive_upsample(x)
        return x


class PositionalEncoding(nn.Module):
    """Sinusoidal positional encoding for Transformer encoder."""

    def __init__(self, d_model: int, max_len: int = 600, dropout: float = 0.1) -> None:
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe       = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(
            torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model)
        )
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer("pe", pe.unsqueeze(0))  # (1, max_len, d_model)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x + self.pe[:, : x.size(1), :]
        return self.dropout(x)


class EEGTransformerEncoder(nn.Module):
    """4-layer Transformer encoder over WaveNet features + spectral features."""

    def __init__(
        self,
        cnn_out_dim: int = 64,
        n_spectral_features: int = 9,
        d_model: int = 128,
        n_heads: int = 4,
        n_layers: int = 4,
        ffn_dim: int = 256,
        dropout: float = 0.1,
        n_output_vectors: int = 256,
    ) -> None:
        super().__init__()
        self.cnn_proj      = nn.Linear(cnn_out_dim, d_model)
        self.spectral_proj = nn.Linear(n_spectral_features, d_model)
        self.spectral_pool = nn.AdaptiveAvgPool1d(n_output_vectors)
        self.pos_enc       = PositionalEncoding(d_model, max_len=n_output_vectors, dropout=dropout)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=n_heads,
            dim_feedforward=ffn_dim, dropout=dropout, batch_first=True,
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
        self.out_proj    = nn.Linear(d_model, d_model)

    def forward(
        self,
        cnn_features:      torch.Tensor,
        spectral_features: torch.Tensor,
        sqi_mask:          Optional[torch.Tensor] = None,
    ) -> torch.Tensor:
        """
        Parameters
        ----------
        cnn_features      : Tensor (B, cnn_out_dim, n_output_vectors)
        spectral_features : Tensor (B, T_scalar, n_spectral_features)
        sqi_mask          : Tensor (B, T_scalar)  optional

        Returns
        -------
        embedding : Tensor (B, 128)
        """
        # CNN features → sequence of d_model vectors
        cnn_seq = self.cnn_proj(cnn_features.permute(0, 2, 1))     # (B, N_vec, d_model)

        # Spectral features → pool to match N_vec
        sp_proj = self.spectral_proj(spectral_features)             # (B, T_scalar, d_model)
        sp_proj = self.spectral_pool(sp_proj.permute(0, 2, 1))     # (B, d_model, N_vec)
        sp_proj = sp_proj.permute(0, 2, 1)                         # (B, N_vec, d_model)

        fused   = self.pos_enc(cnn_seq + sp_proj)
        encoded = self.transformer(fused)                           # (B, N_vec, d_model)
        embedding = self.out_proj(encoded.mean(dim=1))             # (B, d_model)
        return embedding

# %%
class EEGModel(nn.Module):
    """Full EEG Model 3: WaveNet CNN → Transformer + task heads.

    Architecture
    ------------
    1. WaveNetEncoder  : raw EEG (B, 2, 3840) @ 128 Hz → CNN features (B, 64, 256)
    2. EEGTransformerEncoder : CNN + spectral features → 128-dim embedding
    3. IOH head        : binary classification for 3 horizons (5, 10, 15 min)
    4. N/H head        : 3-class classification (adequate / nociception / hypnosis)

    Stage 0 (MSM pretraining) uses only the WaveNet encoder + MSM decoder.
    """

    def __init__(self, config: Dict) -> None:
        super().__init__()
        self.config = config

        self.wavenet = WaveNetEncoder(
            n_input_channels=2,
            residual_channels=config["wavenet_residual_channels"],
            skip_channels=config["wavenet_skip_channels"],
            kernel_size=config["wavenet_kernel_size"],
            dilations=config["wavenet_dilations"],
            n_output_vectors=config["wavenet_n_output_vectors"],
        )
        self.msm_decoder = MSMDecoder(
            cnn_out_dim=config["wavenet_skip_channels"],
            n_output_samples=config["eeg_samples_per_step"],  # 3840
            n_eeg_channels=2,
        )
        self.transformer_enc = EEGTransformerEncoder(
            cnn_out_dim=config["wavenet_skip_channels"],
            n_spectral_features=config["transformer_n_spectral_features"],
            d_model=config["transformer_d_model"],
            n_heads=config["transformer_n_heads"],
            n_layers=config["transformer_n_layers"],
            ffn_dim=config["transformer_ffn_dim"],
            dropout=config["transformer_dropout"],
            n_output_vectors=config["wavenet_n_output_vectors"],
        )
        emb_dim = config["embedding_dim"]
        self.ioh_head_5  = nn.Linear(emb_dim, 1)
        self.ioh_head_10 = nn.Linear(emb_dim, 1)
        self.ioh_head_15 = nn.Linear(emb_dim, 1)
        self.nh_head     = nn.Linear(emb_dim, config["nh_n_classes"])

    def encode(
        self,
        wav:         torch.Tensor,
        x_spectral:  torch.Tensor,
        sqi_mask:    Optional[torch.Tensor] = None,
    ) -> torch.Tensor:
        """Run WaveNet + Transformer to produce 128-dim embedding.

        Parameters
        ----------
        wav        : Tensor (B, 2, 3840)
        x_spectral : Tensor (B, T, n_spectral_features)
        sqi_mask   : Tensor (B, T) optional

        Returns
        -------
        Tensor (B, 128)
        """
        cnn_feat  = self.wavenet(wav)
        embedding = self.transformer_enc(cnn_feat, x_spectral, sqi_mask)
        return embedding

    def forward(
        self,
        wav:              torch.Tensor,
        x_spectral:       torch.Tensor,
        sqi_mask:         Optional[torch.Tensor] = None,
        modality_present: Optional[torch.Tensor] = None,
    ) -> Dict[str, torch.Tensor]:
        """Full forward pass for supervised training.

        Returns
        -------
        Dict with keys: 'embedding', 'ioh_5', 'ioh_10', 'ioh_15', 'nh'
        """
        embedding = self.encode(wav, x_spectral, sqi_mask)

        # Zero-out embedding where SQI < 50 (modality_present = False)
        if modality_present is not None:
            embedding = embedding * modality_present.float().unsqueeze(-1)

        return {
            "embedding": embedding,
            "ioh_5":     self.ioh_head_5(embedding),
            "ioh_10":    self.ioh_head_10(embedding),
            "ioh_15":    self.ioh_head_15(embedding),
            "nh":        self.nh_head(embedding),
        }

    def forward_msm(self, wav: torch.Tensor) -> torch.Tensor:
        """MSM pretraining forward pass.

        Parameters
        ----------
        wav : Tensor (B, 2, 3840) — partially masked raw EEG at 128 Hz

        Returns
        -------
        recon : Tensor (B, 2, 3840)
        """
        cnn_feat = self.wavenet(wav)
        return self.msm_decoder(cnn_feat)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 12. Loss functions
# ─────────────────────────────────────────────────────────────────────────────
def ioh_bce_loss(
    pred:     torch.Tensor,
    target:   torch.Tensor,
    sqi_mask: Optional[torch.Tensor] = None,
) -> torch.Tensor:
    """Binary cross-entropy loss for IOH prediction, gated by SQI mask.

    sqi_mask is sqi_end_gate of shape (B,) — a per-sample scalar gate.
    FIX: compute in fp32 to avoid fp16 overflow. Also, when all samples in
    a batch have SQI=0, return 0.0 loss instead of 0/1=0 (avoids misleading
    zero gradient with no valid samples).
    """
    # FIX: fp32 for numerical stability
    bce = F.binary_cross_entropy_with_logits(pred.float(), target.float(), reduction="none")
    if sqi_mask is not None:
        gate    = sqi_mask.float().unsqueeze(1)   # (B,) → (B, 1)
        n_valid = gate.sum()
        if n_valid < 1.0:
            return torch.tensor(0.0, device=pred.device, dtype=pred.dtype)
        return (bce * gate).sum() / n_valid
    return bce.mean()


def focal_loss(
    logits:          torch.Tensor,
    targets:         torch.Tensor,
    gamma:           float = 2.0,
    class_weights:   Optional[torch.Tensor] = None,
    label_smoothing: float = 0.15,
) -> torch.Tensor:
    """Focal loss for N/H multi-class classification with label smoothing.

    FIX: compute in fp32 regardless of AMP context — highly skewed class weights
    (e.g. 0.001 vs 2.98) can cause the weighted loss to overflow fp16 → NaN.
    Also clamps the final loss to prevent Inf from extreme weights.
    """
    n_classes = logits.size(-1)
    # FIX: force fp32 computation to avoid fp16 overflow with skewed class weights
    logits_f = logits.float()
    with torch.no_grad():
        smoothed = torch.zeros_like(logits_f).scatter_(1, targets.unsqueeze(1), 1.0)
        smoothed = smoothed * (1 - label_smoothing) + label_smoothing / n_classes

    log_probs = F.log_softmax(logits_f, dim=-1)
    ce        = -(smoothed * log_probs).sum(dim=-1)

    probs  = torch.exp(log_probs)
    pt     = (probs * F.one_hot(targets, n_classes).float()).sum(dim=-1)
    loss   = (1.0 - pt).pow(gamma) * ce

    if class_weights is not None:
        # FIX: clamp weights before applying — extreme values (e.g. 2.98 vs 0.001) blow up fp16
        w = class_weights.float().clamp(max=10.0)
        loss = loss * w[targets]
    return loss.clamp(max=100.0).mean()   # FIX: clamp to prevent single-sample Inf


def msm_reconstruction_loss(
    recon:    torch.Tensor,
    original: torch.Tensor,
    mask:     torch.Tensor,
) -> torch.Tensor:
    """MSE loss computed only over masked positions.

    FIX: guard against NaN/Inf in recon or original (can occur early in training
    with AMP). Uses nan_to_num and clamps the squared error to prevent Inf loss.

    Parameters
    ----------
    recon    : Tensor (B, 2, T)
    original : Tensor (B, 2, T)
    mask     : Tensor (B, T) — 1.0 at masked positions
    """
    # FIX: sanitise tensors before computing loss to avoid NaN propagation
    recon    = torch.nan_to_num(recon,    nan=0.0, posinf=0.0, neginf=0.0)
    original = torch.nan_to_num(original, nan=0.0, posinf=0.0, neginf=0.0)
    mask_expanded = mask.unsqueeze(1).expand_as(recon)
    n_masked      = mask_expanded.sum().clamp(min=1.0)
    sq_err        = ((recon - original) ** 2).clamp(max=1e6)   # FIX: clamp prevents Inf
    return (sq_err * mask_expanded).sum() / n_masked


def compute_class_weights(labels_nh: List[int], n_classes: int = 3) -> torch.Tensor:
    """Compute inverse frequency class weights from training label list."""
    arr     = np.array(labels_nh, dtype=np.int64)
    counts  = np.maximum(np.bincount(arr, minlength=n_classes).astype(np.float32), 1.0)
    weights = 1.0 / counts
    weights = weights / weights.sum() * n_classes
    return torch.FloatTensor(weights)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 13. Metrics
# ─────────────────────────────────────────────────────────────────────────────
def compute_metrics(
    ioh_preds:   Dict[str, np.ndarray],
    ioh_targets: Dict[str, np.ndarray],
    nh_preds:    np.ndarray,
    nh_targets:  np.ndarray,
) -> Dict[str, float]:
    """Compute AUROC, AUPRC for IOH and balanced accuracy/macro-F1 for N/H.

    FIX: replace NaN/Inf predictions with 0.5 before passing to sklearn —
    NaN preds occur when model weights are corrupted (all-NaN batches during
    training left corrupted gradients). This prevents the ValueError crash.
    """
    from sklearn.metrics import (
        average_precision_score, balanced_accuracy_score,
        f1_score, roc_auc_score,
    )
    metrics: Dict[str, float] = {}
    for key in ["ioh_5", "ioh_10", "ioh_15"]:
        p = np.nan_to_num(ioh_preds[key], nan=0.5, posinf=1.0, neginf=0.0)  # FIX
        t = ioh_targets[key]
        if len(np.unique(t)) < 2:
            metrics[f"auroc_{key}"] = float("nan")
            metrics[f"auprc_{key}"] = float("nan")
        else:
            try:
                metrics[f"auroc_{key}"] = float(roc_auc_score(t, p))
                metrics[f"auprc_{key}"] = float(average_precision_score(t, p))
            except ValueError as e:
                log.warning(f"Metrics error for {key}: {e}")
                metrics[f"auroc_{key}"] = float("nan")
                metrics[f"auprc_{key}"] = float("nan")
    try:
        metrics["nh_balanced_acc"] = float(balanced_accuracy_score(nh_targets, nh_preds))
        metrics["nh_macro_f1"]     = float(f1_score(nh_targets, nh_preds, average="macro", zero_division=0))
    except ValueError as e:
        log.warning(f"N/H metrics error: {e}")
        metrics["nh_balanced_acc"] = float("nan")
        metrics["nh_macro_f1"]     = float("nan")
    return metrics

# %%
# ─────────────────────────────────────────────────────────────────────────────
# MSM masking helper
#   span = 64 samples = 0.5 s at 128 Hz
# ─────────────────────────────────────────────────────────────────────────────
def apply_msm_mask(
    wav:    torch.Tensor,
    config: Dict,
) -> Tuple[torch.Tensor, torch.Tensor]:
    """Randomly mask 20 % of raw EEG with contiguous spans of 0.5 s (64 samples @ 128 Hz).

    Parameters
    ----------
    wav    : Tensor (B, 2, T)
    config : Dict

    Returns
    -------
    wav_masked : Tensor (B, 2, T)
    mask       : Tensor (B, T) — 1.0 at masked positions
    """
    B, C, T = wav.shape
    mask        = torch.zeros(B, T, device=wav.device)
    span        = config["msm_mask_span_samples"]          # 64
    target_masked = int(config["msm_mask_prob"] * T)       # 20 % of T

    # FIX: sanitise input — NaN in raw EEG (e.g. leading/trailing gaps) → NaN MSM loss
    wav        = torch.nan_to_num(wav, nan=0.0)
    wav_masked = wav.clone()
    for b in range(B):
        n_masked, attempts = 0, 0
        while n_masked < target_masked and attempts < 1000:
            start = random.randint(0, T - span)
            mask[b, start: start + span] = 1.0
            wav_masked[b, :, start: start + span] = 0.0
            n_masked = int(mask[b].sum().item())
            attempts += 1

    return wav_masked, mask

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 14a. Stage 0 — MSM pretraining epoch
# ─────────────────────────────────────────────────────────────────────────────
def pretrain_one_epoch_msm(
    model:      EEGModel,
    loader:     DataLoader,
    optimizer:  torch.optim.Optimizer,
    amp_scaler: GradScaler,
    config:     Dict,
    device:     torch.device,
) -> float:
    """Run one MSM pretraining epoch.

    Returns
    -------
    float
        Mean reconstruction loss over the epoch.
    """
    model.train()
    total_loss     = 0.0
    n_batches      = 0
    grad_acc_steps = config["gradient_accumulation_steps"]
    optimizer.zero_grad()

    for step, batch in enumerate(tqdm(loader, desc="MSM Pretrain", leave=False)):
        # wav from Dataset: (B, 3840, 2) → permute → (B, 2, 3840)
        wav = batch["wav"].to(device).permute(0, 2, 1)
        wav_masked, mask = apply_msm_mask(wav, config)

        with autocast(device_type=device.type):
            recon = model.forward_msm(wav_masked)
            loss  = msm_reconstruction_loss(recon, wav, mask) / grad_acc_steps

        # FIX: guard BEFORE backward to prevent corrupted gradients
        loss_val = loss.item() * grad_acc_steps
        if not math.isfinite(loss_val):
            log.warning(f"MSM step {step}: non-finite loss {loss_val:.4g}, skipping step entirely")
            optimizer.zero_grad()
            continue

        amp_scaler.scale(loss).backward()
        if (step + 1) % grad_acc_steps == 0:
            amp_scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), config["max_grad_norm"])
            amp_scaler.step(optimizer)
            amp_scaler.update()
            optimizer.zero_grad()

        total_loss += loss_val
        n_batches  += 1

    return total_loss / max(n_batches, 1)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 14b. Supervised training epoch
# ─────────────────────────────────────────────────────────────────────────────
def train_one_epoch(
    model:            EEGModel,
    loader:           DataLoader,
    optimizer:        torch.optim.Optimizer,
    amp_scaler:       GradScaler,
    class_weights_nh: torch.Tensor,
    config:           Dict,
    device:           torch.device,
) -> float:
    """Run one supervised training epoch.

    FIX (v3): Three NaN sources fixed:
    1. AMP fp16 overflow in supervised forward: loss terms are now cast to fp32
       *before* the isfinite check, so NaN is detected from fp16 overflow rather
       than silently becoming zero.  The focal_loss and ioh_bce_loss already cast
       to fp32 internally; we just make it explicit by calling .float() on logits.
    2. AMP scaler internal counters could desync when many steps were skipped:
       amp_scaler.update() is now called after each skipped accumulation boundary
       so the scaler can still adjust its scale factor downward.
    3. Partial-batch gradient accumulation at epoch end: a flush step is added so
       gradients from the last (<grad_acc_steps) batches are never silently dropped.

    Returns
    -------
    float
        Mean combined loss over the epoch.
    """
    model.train()
    total_loss     = 0.0
    n_batches      = 0
    grad_acc_steps = config["gradient_accumulation_steps"]
    class_weights_nh = class_weights_nh.to(device)
    optimizer.zero_grad()
    had_gradient   = False   # track whether any gradient is pending

    for step, batch in enumerate(tqdm(loader, desc="Train", leave=False)):
        wav = batch["wav"].to(device).permute(0, 2, 1)   # (B, 2, 3840)
        x   = batch["x"].to(device)                      # (B, 1800, 14)
        x_spectral       = x[:, :, -CONFIG["transformer_n_spectral_features"]:]  # (B, 1800, 6)
        sqi_mask         = batch["sqi_flag"].to(device)                           # (B, 1800)
        modality_present = batch["modality_present"].squeeze(-1).to(device)       # (B,)
        label_ioh_5      = batch["label_ioh_5"].to(device)
        label_ioh_10     = batch["label_ioh_10"].to(device)
        label_ioh_15     = batch["label_ioh_15"].to(device)
        label_nh         = batch["label_nh"].squeeze(-1).to(device)
        sqi_end_gate     = sqi_mask[:, -1]                                        # (B,)

        with autocast(device_type=device.type):
            out = model(wav, x_spectral, sqi_mask, modality_present)
            # FIX: cast logits to fp32 before loss computation to prevent fp16
            # overflow in focal_loss with extreme class weights (0.001 vs 2.98).
            loss_ioh5  = ioh_bce_loss(out["ioh_5"].float(),  label_ioh_5,  sqi_end_gate)
            loss_ioh10 = ioh_bce_loss(out["ioh_10"].float(), label_ioh_10, sqi_end_gate)
            loss_ioh15 = ioh_bce_loss(out["ioh_15"].float(), label_ioh_15, sqi_end_gate)
            loss_nh    = focal_loss(
                out["nh"].float(), label_nh,
                gamma=config["nh_focal_gamma"],
                class_weights=class_weights_nh,
                label_smoothing=config["nh_label_smoothing"],
            )
            loss = ((loss_ioh5 + loss_ioh10 + loss_ioh15) / 3.0 + loss_nh) / grad_acc_steps

        loss_val = loss.item() * grad_acc_steps
        if not math.isfinite(loss_val):
            log.warning(f"Sup step {step}: non-finite loss {loss_val:.4g}, skipping step entirely")
            optimizer.zero_grad()
            had_gradient = False
            # FIX: notify AMP scaler that we skipped so it can adjust scale downward
            if (step + 1) % grad_acc_steps == 0:
                amp_scaler.update()
            continue

        amp_scaler.scale(loss).backward()
        had_gradient = True

        if (step + 1) % grad_acc_steps == 0:
            amp_scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), config["max_grad_norm"])
            amp_scaler.step(optimizer)
            amp_scaler.update()
            optimizer.zero_grad()
            had_gradient = False

        total_loss += loss_val
        n_batches  += 1

    # FIX: flush any pending gradients from a partial final accumulation window
    if had_gradient:
        amp_scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), config["max_grad_norm"])
        amp_scaler.step(optimizer)
        amp_scaler.update()
        optimizer.zero_grad()

    return total_loss / max(n_batches, 1)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 15. Validation
# ─────────────────────────────────────────────────────────────────────────────
def validate(
    model:            EEGModel,
    loader:           DataLoader,
    class_weights_nh: torch.Tensor,
    config:           Dict,
    device:           torch.device,
) -> Tuple[float, Dict[str, float]]:
    """Run one validation pass and return loss + metrics."""
    model.eval()
    total_loss       = 0.0
    n_batches        = 0
    class_weights_nh = class_weights_nh.to(device)

    all_ioh5_pred,  all_ioh10_pred,  all_ioh15_pred  = [], [], []
    all_ioh5_true,  all_ioh10_true,  all_ioh15_true  = [], [], []
    all_nh_pred,    all_nh_true                       = [], []

    with torch.no_grad():
        for batch in tqdm(loader, desc="Validate", leave=False):
            wav              = batch["wav"].to(device).permute(0, 2, 1)
            x                = batch["x"].to(device)
            x_spectral       = x[:, :, -CONFIG["transformer_n_spectral_features"]:]
            sqi_mask         = batch["sqi_flag"].to(device)
            modality_present = batch["modality_present"].squeeze(-1).to(device)
            label_ioh_5      = batch["label_ioh_5"].to(device)
            label_ioh_10     = batch["label_ioh_10"].to(device)
            label_ioh_15     = batch["label_ioh_15"].to(device)
            label_nh         = batch["label_nh"].squeeze(-1).to(device)
            sqi_end_gate     = sqi_mask[:, -1]

            with autocast(device_type=device.type):
                out        = model(wav, x_spectral, sqi_mask, modality_present)
                loss_ioh5  = ioh_bce_loss(out["ioh_5"],  label_ioh_5,  sqi_end_gate)
                loss_ioh10 = ioh_bce_loss(out["ioh_10"], label_ioh_10, sqi_end_gate)
                loss_ioh15 = ioh_bce_loss(out["ioh_15"], label_ioh_15, sqi_end_gate)
                loss_nh    = focal_loss(
                    out["nh"], label_nh,
                    gamma=config["nh_focal_gamma"],
                    class_weights=class_weights_nh,
                    label_smoothing=config["nh_label_smoothing"],
                )
                loss = (loss_ioh5 + loss_ioh10 + loss_ioh15) / 3.0 + loss_nh

            total_loss += loss.item()
            n_batches  += 1

            # FIX: nan_to_num before numpy — corrupted model weights can produce NaN sigmoid
            all_ioh5_pred.append(torch.nan_to_num(torch.sigmoid(out["ioh_5"]),  nan=0.5).cpu().numpy())
            all_ioh10_pred.append(torch.nan_to_num(torch.sigmoid(out["ioh_10"]), nan=0.5).cpu().numpy())
            all_ioh15_pred.append(torch.nan_to_num(torch.sigmoid(out["ioh_15"]), nan=0.5).cpu().numpy())
            all_ioh5_true.append(label_ioh_5.cpu().numpy())
            all_ioh10_true.append(label_ioh_10.cpu().numpy())
            all_ioh15_true.append(label_ioh_15.cpu().numpy())
            # FIX: nan_to_num for nh logits before argmax
            nh_out_safe = torch.nan_to_num(out["nh"], nan=0.0)
            all_nh_pred.append(nh_out_safe.argmax(dim=-1).cpu().numpy())
            all_nh_true.append(label_nh.cpu().numpy())

    val_loss = total_loss / max(n_batches, 1)
    ioh_preds   = {k: np.concatenate(v).flatten() for k, v in
                   zip(["ioh_5","ioh_10","ioh_15"],[all_ioh5_pred,all_ioh10_pred,all_ioh15_pred])}
    ioh_targets = {k: np.concatenate(v).flatten() for k, v in
                   zip(["ioh_5","ioh_10","ioh_15"],[all_ioh5_true,all_ioh10_true,all_ioh15_true])}
    nh_preds    = np.concatenate(all_nh_pred)
    nh_targets  = np.concatenate(all_nh_true)

    metrics = compute_metrics(ioh_preds, ioh_targets, nh_preds, nh_targets)
    return val_loss, metrics

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 16. EarlyStopping
# ─────────────────────────────────────────────────────────────────────────────
class EarlyStopping:
    """Early stopping with best-model checkpointing.

    Stops training when val loss has not improved for `patience` epochs.
    """

    def __init__(self, patience: int = 8, checkpoint_path: str = "best_model.pt") -> None:
        self.patience        = patience
        self.checkpoint_path = checkpoint_path
        self.best_loss       = float("inf")
        self.counter         = 0
        self.should_stop     = False

    def step(self, val_loss: float, model: nn.Module) -> None:
        if val_loss < self.best_loss:
            self.best_loss = val_loss
            self.counter   = 0
            torch.save(model.state_dict(), self.checkpoint_path)
            log.info(f"  ✓ New best val_loss={val_loss:.6f} — checkpoint saved")
        else:
            self.counter += 1
            log.info(f"  EarlyStopping counter: {self.counter}/{self.patience}")
            if self.counter >= self.patience:
                self.should_stop = True
                log.info("  Early stopping triggered.")

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 17. train_model — orchestrates Stage 0 + Stage 1
# ─────────────────────────────────────────────────────────────────────────────
def train_model(
    model:            EEGModel,
    train_loader:     DataLoader,
    val_loader:       DataLoader,
    class_weights_nh: torch.Tensor,
    config:           Dict,
    device:           torch.device,
) -> EEGModel:
    """Train in two stages: MSM pretraining then supervised fine-tuning.

    FIX (v3):
    - A FRESH GradScaler (init_scale=256) is created for Stage 1 so the MSM
      scaler's large inherited scale factor does not cause fp16 overflow in the
      first supervised forward pass through randomly-initialised head layers.
    - model.float() is called after saving the MSM checkpoint to convert all
      parameters to fp32 before supervised training begins.  This prevents
      overflow when the untrained spectral_proj / IOH heads interact with the
      pretrained encoder under AMP.
    - A 2-epoch linear LR warm-up is prepended to the cosine schedule so the
      randomly-initialised head layers receive small updates before the full LR
      is applied.

    Returns
    -------
    EEGModel
        Best model loaded from checkpoint.
    """
    model = model.to(device)

    # ── Stage 0: MSM pretraining ──────────────────────────────────────────────
    log.info("=== Stage 0: MSM Pretraining ===")
    amp_scaler_msm = GradScaler(device=device.type)
    optimizer_msm  = torch.optim.Adam(
        model.parameters(), lr=config["msm_lr"], weight_decay=config["weight_decay"]
    )
    msm_loader = DataLoader(
        train_loader.dataset,
        batch_size=config["msm_batch_size"],
        shuffle=True, num_workers=0, pin_memory=True,
    )
    for epoch in range(1, config["msm_epochs"] + 1):
        msm_loss = pretrain_one_epoch_msm(
            model, msm_loader, optimizer_msm, amp_scaler_msm, config, device
        )
        log.info(f"[MSM] Epoch {epoch}/{config['msm_epochs']}  loss={msm_loss:.6f}")

    torch.save(model.state_dict(), config["checkpoint_msm"])
    log.info(f"MSM checkpoint saved → {config['checkpoint_msm']}")

    # ── Stage 1: Supervised fine-tuning ──────────────────────────────────────
    log.info("=== Stage 1: Supervised Fine-tuning ===")

    # FIX: convert model weights to fp32 after MSM to prevent fp16 overflow
    # when the untrained head layers are applied on top of the pretrained encoder.
    model.float()
    log.info("Model weights converted to fp32 before supervised training.")

    # FIX: fresh scaler with conservative init_scale so early supervised steps
    # don't inherit the MSM scaler's potentially large scale factor.
    amp_scaler_sup = GradScaler(device=device.type, init_scale=256.0)

    optimizer_sup = torch.optim.AdamW(
        model.parameters(), lr=config["sup_lr"], weight_decay=config["weight_decay"]
    )

    # FIX: 2-epoch linear warm-up so randomly-init head layers stabilise before
    # the full LR is applied.  After warm-up, cosine annealing takes over.
    warmup_epochs = 2
    def lr_lambda(epoch_idx: int) -> float:
        if epoch_idx < warmup_epochs:
            return float(epoch_idx + 1) / float(warmup_epochs)
        # cosine phase
        progress = (epoch_idx - warmup_epochs) / max(config["sup_epochs"] - warmup_epochs, 1)
        return max(1e-6 / config["sup_lr"],
                   0.5 * (1.0 + math.cos(math.pi * progress)))

    scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer_sup, lr_lambda=lr_lambda)

    early_stop = EarlyStopping(
        patience=config["early_stopping_patience"],
        checkpoint_path=config["checkpoint_sup"],
    )

    for epoch in range(1, config["sup_epochs"] + 1):
        t0         = time.time()
        train_loss = train_one_epoch(
            model, train_loader, optimizer_sup, amp_scaler_sup,
            class_weights_nh, config, device,
        )
        val_loss, val_metrics = validate(model, val_loader, class_weights_nh, config, device)
        scheduler.step()
        elapsed = time.time() - t0
        log.info(
            f"[Sup] Epoch {epoch}/{config['sup_epochs']}  "
            f"train_loss={train_loss:.4f}  val_loss={val_loss:.4f}  "
            f"auroc_ioh5={val_metrics.get('auroc_ioh_5', float('nan')):.3f}  "
            f"nh_f1={val_metrics.get('nh_macro_f1', float('nan')):.3f}  "
            f"time={elapsed:.1f}s"
        )
        early_stop.step(val_loss, model)
        if early_stop.should_stop:
            break

    model.load_state_dict(torch.load(config["checkpoint_sup"], map_location=device,
                                     weights_only=True))
    log.info("Best supervised model loaded from checkpoint.")
    return model

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 18. Test evaluation
# ─────────────────────────────────────────────────────────────────────────────
def evaluate_test(
    model:            EEGModel,
    test_loader:      DataLoader,
    class_weights_nh: torch.Tensor,
    config:           Dict,
    device:           torch.device,
) -> Dict[str, float]:
    """Evaluate model on held-out test set and print full metrics."""
    test_loss, metrics = validate(model, test_loader, class_weights_nh, config, device)
    log.info("=== Test Set Evaluation ===")
    log.info(f"  Test loss: {test_loss:.6f}")
    for k, v in metrics.items():
        log.info(f"  {k}: {v:.4f}")
    return metrics

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 19. SHAP explanation
# ─────────────────────────────────────────────────────────────────────────────
def explain_with_shap(
    model:       EEGModel,
    test_loader: DataLoader,
    config:      Dict,
    device:      torch.device,
) -> None:
    """Generate SHAP feature importance plot for spectral + scalar features.

    Uses DeepExplainer on a spectral proxy forward pass → IOH-5 head.
    Full raw EEG SHAP is computationally infeasible; spectral features are used.
    Saves plot to config['shap_output'].
    """
    log.info("Computing SHAP values …")
    bg_x_list,   test_x_list = [], []
    max_bg, max_test          = 32, 64

    for batch in test_loader:
        x        = batch["x"].to(device)
        spectral = x[:, :, -CONFIG["transformer_n_spectral_features"]:]  # (B, 1800, 9)
        spectral_mean = spectral.mean(dim=1)                              # (B, 9)
        if len(bg_x_list) * spectral_mean.size(0) < max_bg:
            bg_x_list.append(spectral_mean.detach().cpu())
        if len(test_x_list) * spectral_mean.size(0) < max_test:
            test_x_list.append(spectral_mean.detach().cpu())

    if not bg_x_list or not test_x_list:
        log.warning("Not enough data for SHAP — skipping")
        return

    bg_x   = torch.cat(bg_x_list,   dim=0)[:max_bg]
    test_x = torch.cat(test_x_list, dim=0)[:max_test]

    class SpectralWrapper(nn.Module):
        def __init__(self, enc: EEGModel) -> None:
            super().__init__()
            self.enc = enc

        def forward(self, sp: torch.Tensor) -> torch.Tensor:
            # Expand (B, 9) → (B, N_vec, 9) and project through spectral_proj
            N_vec    = CONFIG["wavenet_n_output_vectors"]
            sp_exp   = sp.unsqueeze(1).expand(-1, N_vec, -1)
            proj     = self.enc.transformer_enc.spectral_proj(sp_exp)  # (B, N_vec, 128)
            emb      = proj.mean(dim=1)                                # (B, 128)
            return self.enc.ioh_head_5(emb)

    wrapper = SpectralWrapper(model).to(device).eval()

    try:
        explainer   = shap.DeepExplainer(wrapper, bg_x.to(device))
        shap_values = explainer.shap_values(test_x.to(device))

        feature_names = ["delta_power", "theta_power", "alpha_power", "beta_power",
                         "SEF95", "BSR", "BIS", "EMG", "SR"]
        fig, ax = plt.subplots(figsize=(10, 5))
        ax.barh(feature_names, np.abs(np.array(shap_values)).mean(axis=0), color="steelblue")
        ax.set_xlabel("Mean |SHAP value|")
        ax.set_title("Model 3 — EEG Spectral Feature Importance (IOH-5 min)")
        plt.tight_layout()
        plt.savefig(config["shap_output"], dpi=150)
        plt.close()
        log.info(f"SHAP plot saved → {config['shap_output']}")
    except Exception as exc:
        log.warning(f"SHAP computation failed: {exc}")

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 20. Prediction visualisation
# ─────────────────────────────────────────────────────────────────────────────
def plot_predictions(
    model:       EEGModel,
    test_loader: DataLoader,
    config:      Dict,
    device:      torch.device,
    n_cases:     int = 5,
) -> None:
    """Plot IOH-5 predicted probability vs ground truth for n_cases samples.

    Saves to config['pred_output'].
    """
    model.eval()
    all_pred, all_true, all_caseids = [], [], []

    with torch.no_grad():
        for batch in test_loader:
            wav              = batch["wav"].to(device).permute(0, 2, 1)
            x                = batch["x"].to(device)
            x_spectral       = x[:, :, -CONFIG["transformer_n_spectral_features"]:]
            sqi_mask         = batch["sqi_flag"].to(device)
            modality_present = batch["modality_present"].squeeze(-1).to(device)

            out        = model(wav, x_spectral, sqi_mask, modality_present)
            pred_proba = torch.sigmoid(out["ioh_5"]).cpu().numpy().flatten()
            true_label = batch["label_ioh_5"].cpu().numpy().flatten()
            cids       = batch["caseid"]

            all_pred.extend(pred_proba.tolist())
            all_true.extend(true_label.tolist())
            all_caseids.extend(cids.tolist() if isinstance(cids, torch.Tensor) else list(cids))

            if len(all_pred) >= n_cases * 50:
                break

    unique_cases = list(dict.fromkeys(all_caseids))[:n_cases]
    fig, axes   = plt.subplots(n_cases, 1, figsize=(12, 3 * n_cases), squeeze=False)

    for ax_row, cid in zip(axes, unique_cases):
        ax     = ax_row[0]
        idxs   = [i for i, c in enumerate(all_caseids) if c == cid]
        pred_c = [all_pred[i] for i in idxs]
        true_c = [all_true[i] for i in idxs]
        t      = list(range(len(pred_c)))
        ax.plot(t, pred_c, label="P(IOH-5min)", color="steelblue")
        ax.fill_between(t, true_c, alpha=0.3, color="red", label="IOH true")
        ax.set_ylim(0, 1)
        ax.set_ylabel("Prob")
        ax.set_title(f"Case {cid}")
        ax.legend(loc="upper right", fontsize=8)

    axes[-1][0].set_xlabel("Window index")
    plt.suptitle("Model 3 — EEG IOH-5 Predictions vs Ground Truth", fontsize=13)
    plt.tight_layout()
    plt.savefig(config["pred_output"], dpi=150)
    plt.close()
    log.info(f"Prediction plot saved → {config['pred_output']}")

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 21. Main entry point
# ─────────────────────────────────────────────────────────────────────────────
def main() -> None:
    """End-to-end pipeline: data loading, preprocessing, training, evaluation."""
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    log.info(f"Using device: {device}")

    # ── 4a: Clinical metadata ─────────────────────────────────────────────────
    clinical_df = load_clinical_metadata(CONFIG)

    # ── Determine valid case IDs (BIS monitor cases only) ────────────────────
    try:
        bis_cases = set(range(1,21))
        log.info(f"vitaldb.caseids_bis: {len(bis_cases)} cases with BIS monitor")
    except AttributeError:
        log.warning("vitaldb.caseids_bis not available — iterating all 6388 cases")
        bis_cases = set(range(1, 6389))

    valid_caseids = sorted(bis_cases)
    log.info(f"Attempting to load {len(valid_caseids)} BIS cases")

    # ── 4b: Load waveform data ─────────────────────────────────────────────────
    wav_data, scalar_data = load_waveform_data(valid_caseids, CONFIG)

    # ── 8: Split cases BEFORE window generation (no leakage) ──────────────────
    all_loaded_caseids = sorted(set(wav_data.keys()) & set(scalar_data.keys()))
    train_caseids, val_caseids, test_caseids = split_cases(
        all_loaded_caseids,
        val_frac=CONFIG["val_frac"],
        test_frac=CONFIG["test_frac"],
        seed=CONFIG["seed"],
    )

    # ── 6: Window generation per split ────────────────────────────────────────
    def _subset(src_dict, keys):
        return {c: src_dict[c] for c in keys if c in src_dict}

    log.info("Generating training windows …")
    train_windows = generate_windows(
        _subset(wav_data, train_caseids), _subset(scalar_data, train_caseids),
        clinical_df, CONFIG
    )
    gc.collect()

    log.info("Generating validation windows …")
    val_windows = generate_windows(
        _subset(wav_data, val_caseids), _subset(scalar_data, val_caseids),
        clinical_df, CONFIG
    )
    gc.collect()

    log.info("Generating test windows …")
    test_windows = generate_windows(
        _subset(wav_data, test_caseids), _subset(scalar_data, test_caseids),
        clinical_df, CONFIG
    )
    del wav_data, scalar_data
    gc.collect()

    if not train_windows:
        log.error("No training windows generated — aborting")
        return

    # ── 7: Fit scalers on training data only ─────────────────────────────────
    scaler_scalar, scaler_spectral, eeg_mean, eeg_std = fit_scalers(train_windows)  # FIX: unpack eeg stats
    train_windows = apply_scalers(train_windows, scaler_scalar, scaler_spectral, eeg_mean, eeg_std)
    val_windows   = apply_scalers(val_windows,   scaler_scalar, scaler_spectral, eeg_mean, eeg_std)
    test_windows  = apply_scalers(test_windows,  scaler_scalar, scaler_spectral, eeg_mean, eeg_std)

    # ── Class weights on training N/H labels ──────────────────────────────────
    class_weights_nh = compute_class_weights(
        [w["label_nh"] for w in train_windows], n_classes=CONFIG["nh_n_classes"]
    )
    log.info(f"N/H class weights: {class_weights_nh.tolist()}")

    # ── 9–10: Datasets and DataLoaders ───────────────────────────────────────
    train_ds = EEGDataset(train_windows)
    val_ds   = EEGDataset(val_windows)
    test_ds  = EEGDataset(test_windows)
    train_loader, val_loader, test_loader = build_dataloaders(train_ds, val_ds, test_ds, CONFIG)

    # ── 11: Model instantiation ───────────────────────────────────────────────
    model    = EEGModel(CONFIG)
    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    log.info(f"EEGModel parameters: {n_params:,}")

    # ── 17: Train (Stage 0 MSM + Stage 1 supervised) ─────────────────────────
    model = train_model(model, train_loader, val_loader, class_weights_nh, CONFIG, device)

    # ── 18: Test evaluation ───────────────────────────────────────────────────
    evaluate_test(model, test_loader, class_weights_nh, CONFIG, device)

    # ── 19: SHAP explanation ──────────────────────────────────────────────────
    explain_with_shap(model, test_loader, CONFIG, device)

    # ── 20: Prediction visualisation ─────────────────────────────────────────
    plot_predictions(model, test_loader, CONFIG, device, n_cases=5)

    log.info("model_3 pipeline complete.")


if __name__ == "__main__":
    main()
# Out:
# 2026-06-13 09:14:39 | INFO     | model_3 | Using device: cuda
# 2026-06-13 09:14:39 | INFO     | model_3 | Loading clinical metadata …
# 2026-06-13 09:14:40 | INFO     | model_3 | Clinical metadata loaded: 6388 rows, ['caseid', 'anestart', 'aneend', 'opstart', 'opend', 'ane_type']
# 2026-06-13 09:14:40 | INFO     | model_3 | vitaldb.caseids_bis: 20 cases with BIS monitor
# 2026-06-13 09:14:40 | INFO     | model_3 | Attempting to load 20 BIS cases
# Loading EEG waveforms: 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# 2026-06-13 09:15:02 | INFO     | model_3 | Loaded waveform data for 20 cases (0 skipped)
# 2026-06-13 09:15:02 | INFO     | model_3 | Split: train=16, val=2, test=2 cases
# 2026-06-13 09:15:02 | INFO     | model_3 | Generating training windows …
# Generating windows:   0%|          | 0/16 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/scipy/signal/_spectral_py.py:1595: UserWarning: nperseg = 512 is greater than input length  = 128, using nperseg = 128
#   freqs, time, Zxx = _spectral_helper(x, x, fs, window, nperseg, noverlap,
# /usr/local/lib/python3.12/dist-packages/scipy/signal/_spectral_py.py:1595: UserWarning: nperseg = 512 is greater than input length  = 256, using nperseg = 256
#   freqs, time, Zxx = _spectral_helper(x, x, fs, window, nperseg, noverlap,
# /usr/local/lib/python3.12/dist-packages/scipy/signal/_spectral_py.py:1595: UserWarning: nperseg = 512 is greater than input length  = 384, using nperseg = 384
#   freqs, time, Zxx = _spectral_helper(x, x, fs, window, nperseg, noverlap,
# Generating windows: 100%|██████████| 16/16 [00:56<00:00,  3.52s/it]
# 2026-06-13 09:15:58 | INFO     | model_3 | Total windows generated: 2564
# 2026-06-13 09:15:58 | INFO     | model_3 | Generating validation windows …
# Generating windows: 100%|██████████| 2/2 [00:07<00:00,  3.58s/it]
# 2026-06-13 09:16:06 | INFO     | model_3 | Total windows generated: 181
# 2026-06-13 09:16:06 | INFO     | model_3 | Generating test windows …
# Generating windows: 100%|██████████| 2/2 [00:00<00:00, 16.63it/s]
# 2026-06-13 09:16:06 | INFO     | model_3 | Total windows generated: 0
# 2026-06-13 09:16:07 | INFO     | model_3 | Scalers fitted on training data.
# 2026-06-13 09:16:08 | INFO     | model_3 | N/H class weights: [0.0012429909547790885, 0.018064800649881363, 2.980692148208618]
# 2026-06-13 09:16:08 | INFO     | model_3 | DataLoaders: train=641 batches, val=46, test=0
# 2026-06-13 09:16:08 | INFO     | model_3 | EEGModel parameters: 1,099,576
# 2026-06-13 09:16:09 | INFO     | model_3 | === Stage 0: MSM Pretraining ===
# 2026-06-13 09:17:46 | INFO     | model_3 | [MSM] Epoch 1/20  loss=0.896350
# 2026-06-13 09:19:22 | INFO     | model_3 | [MSM] Epoch 2/20  loss=0.823488
# 2026-06-13 09:20:58 | INFO     | model_3 | [MSM] Epoch 3/20  loss=0.728279
# 2026-06-13 09:22:33 | INFO     | model_3 | [MSM] Epoch 4/20  loss=0.678616
# 2026-06-13 09:24:09 | INFO     | model_3 | [MSM] Epoch 5/20  loss=0.672227
# 2026-06-13 09:25:45 | INFO     | model_3 | [MSM] Epoch 6/20  loss=0.615555
# 2026-06-13 09:27:20 | INFO     | model_3 | [MSM] Epoch 7/20  loss=0.651710
# 2026-06-13 09:28:56 | INFO     | model_3 | [MSM] Epoch 8/20  loss=0.642558
# 2026-06-13 09:30:32 | INFO     | model_3 | [MSM] Epoch 9/20  loss=0.625677
# 2026-06-13 09:32:08 | INFO     | model_3 | [MSM] Epoch 10/20  loss=0.646597
# 2026-06-13 09:34:01 | INFO     | model_3 | [MSM] Epoch 11/20  loss=0.657548
# 2026-06-13 09:35:43 | INFO     | model_3 | [MSM] Epoch 12/20  loss=0.592189
# 2026-06-13 09:37:18 | INFO     | model_3 | [MSM] Epoch 13/20  loss=0.567056
# 2026-06-13 09:38:54 | INFO     | model_3 | [MSM] Epoch 14/20  loss=0.637069
# 2026-06-13 09:40:30 | INFO     | model_3 | [MSM] Epoch 15/20  loss=0.571684
# 2026-06-13 09:42:06 | INFO     | model_3 | [MSM] Epoch 16/20  loss=0.591484
# 2026-06-13 09:43:42 | INFO     | model_3 | [MSM] Epoch 17/20  loss=0.528861
# 2026-06-13 09:45:17 | INFO     | model_3 | [MSM] Epoch 18/20  loss=0.596855
# 2026-06-13 09:46:53 | INFO     | model_3 | [MSM] Epoch 19/20  loss=0.548464
# 2026-06-13 09:48:29 | INFO     | model_3 | [MSM] Epoch 20/20  loss=0.588115
# 2026-06-13 09:48:29 | INFO     | model_3 | MSM checkpoint saved → ckpt_model_3_msm.pt
# 2026-06-13 09:48:29 | INFO     | model_3 | === Stage 1: Supervised Fine-tuning ===
# Train:   0%|          | 1/641 [00:34<6:10:20, 34.72s/it]2026-06-13 09:49:03 | WARNING  | model_3 | Sup step 1: non-finite loss nan, skipping accumulation
# Train:   0%|          | 2/641 [00:34<2:33:18, 14.39s/it]2026-06-13 09:49:04 | WARNING  | model_3 | Sup step 2: non-finite loss nan, skipping accumulation
# Train:   1%|          | 5/641 [00:35<33:45,  3.18s/it]2026-06-13 09:49:04 | WARNING  | model_3 | Sup step 5: non-finite loss nan, skipping accumulation
# Train:   1%|          | 6/641 [00:35<22:58,  2.17s/it]2026-06-13 09:49:04 | WARNING  | model_3 | Sup step 6: non-finite loss nan, skipping accumulation
# Train:   1%|          | 7/641 [00:35<16:06,  1.52s/it]2026-06-13 09:49:05 | WARNING  | model_3 | Sup step 7: non-finite loss nan, skipping accumulation
# Train:   1%|▏         | 9/641 [00:36<08:37,  1.22it/s]2026-06-13 09:49:05 | WARNING  | model_3 | Sup step 9: non-finite loss nan, skipping accumulation
# Train:   2%|▏         | 11/641 [00:36<05:13,  2.01it/s]2026-06-13 09:49:05 | WARNING  | model_3 | Sup step 11: non-finite loss nan, skipping accumulation
# Train:   2%|▏         | 12/641 [00:36<04:15,  2.46it/s]2026-06-13 09:49:06 | WARNING  | model_3 | Sup step 12: non-finite loss nan, skipping accumulation
# Train:   2%|▏         | 13/641 [00:37<03:46,  2.78it/s]2026-06-13 09:49:06 | WARNING  | model_3 | Sup step 13: non-finite loss nan, skipping accumulation
# Train:   2%|▏         | 14/641 [00:37<03:11,  3.28it/s]2026-06-13 09:49:06 | WARNING  | model_3 | Sup step 14: non-finite loss nan, skipping accumulation
# Train:   2%|▏         | 15/641 [00:37<02:45,  3.78it/s]2026-06-13 09:49:06 | WARNING  | model_3 | Sup step 15: non-finite loss nan, skipping accumulation
# Train:   2%|▏         | 16/641 [00:37<02:33,  4.08it/s]2026-06-13 09:49:06 | WARNING  | model_3 | Sup step 16: non-finite loss nan, skipping accumulation
# Train:   3%|▎         | 17/641 [00:37<02:24,  4.32it/s]2026-06-13 09:49:07 | WARNING  | model_3 | Sup step 17: non-finite loss nan, skipping accumulation
# Train:   3%|▎         | 18/641 [00:38<02:17,  4.54it/s]2026-06-13 09:49:07 | WARNING  | model_3 | Sup step 18: non-finite loss nan, skipping accumulation
# Train:   3%|▎         | 20/641 [00:38<02:08,  4.83it/s]2026-06-13 09:49:07 | WARNING  | model_3 | Sup step 20: non-finite loss nan, skipping accumulation
# Train:   3%|▎         | 21/641 [00:38<02:07,  4.87it/s]2026-06-13 09:49:07 | WARNING  | model_3 | Sup step 21: non-finite loss nan, skipping accumulation
# Train:   4%|▎         | 24/641 [00:39<02:00,  5.11it/s]2026-06-13 09:49:08 | WARNING  | model_3 | Sup step 24: non-finite loss nan, skipping accumulation
# Train:   4%|▍         | 25/641 [00:39<02:02,  5.02it/s]2026-06-13 09:49:08 | WARNING  | model_3 | Sup step 25: non-finite loss nan, skipping accumulation
# Train:   4%|▍         | 26/641 [00:39<02:01,  5.05it/s]2026-06-13 09:49:08 | WARNING  | model_3 | Sup step 26: non-finite loss nan, skipping accumulation
# Train:   4%|▍         | 27/641 [00:39<02:01,  5.04it/s]2026-06-13 09:49:09 | WARNING  | model_3 | Sup step 27: non-finite loss nan, skipping accumulation
# Train:   4%|▍         | 28/641 [00:40<02:11,  4.65it/s]2026-06-13 09:49:09 | WARNING  | model_3 | Sup step 28: non-finite loss nan, skipping accumulation
# Train:   5%|▍         | 29/641 [00:40<02:10,  4.68it/s]2026-06-13 09:49:09 | WARNING  | model_3 | Sup step 29: non-finite loss nan, skipping accumulation
# Train:   5%|▍         | 31/641 [00:40<02:02,  4.96it/s]2026-06-13 09:49:09 | WARNING  | model_3 | Sup step 31: non-finite loss nan, skipping accumulation
# Train:   5%|▍         | 32/641 [00:40<02:01,  5.03it/s]2026-06-13 09:49:10 | WARNING  | model_3 | Sup step 32: non-finite loss nan, skipping accumulation
# Train:   5%|▌         | 33/641 [00:41<02:01,  5.02it/s]2026-06-13 09:49:10 | WARNING  | model_3 | Sup step 33: non-finite loss nan, skipping accumulation
# Train:   5%|▌         | 35/641 [00:41<01:59,  5.09it/s]2026-06-13 09:49:10 | WARNING  | model_3 | Sup step 35: non-finite loss nan, skipping accumulation
# Train:   6%|▌         | 39/641 [00:42<01:58,  5.10it/s]2026-06-13 09:49:11 | WARNING  | model_3 | Sup step 39: non-finite loss nan, skipping accumulation
# Train:   6%|▌         | 40/641 [00:42<01:58,  5.05it/s]2026-06-13 09:49:11 | WARNING  | model_3 | Sup step 40: non-finite loss nan, skipping accumulation
# Train:   7%|▋         | 42/641 [00:42<02:00,  4.98it/s]2026-06-13 09:49:12 | WARNING  | model_3 | Sup step 42: non-finite loss nan, skipping accumulation
# Train:   7%|▋         | 43/641 [00:43<01:59,  5.01it/s]2026-06-13 09:49:12 | WARNING  | model_3 | Sup step 43: non-finite loss nan, skipping accumulation
# Train:   7%|▋         | 44/641 [00:43<01:59,  5.00it/s]2026-06-13 09:49:12 | WARNING  | model_3 | Sup step 44: non-finite loss nan, skipping accumulation
# Train:   7%|▋         | 45/641 [00:43<01:59,  5.01it/s]2026-06-13 09:49:12 | WARNING  | model_3 | Sup step 45: non-finite loss nan, skipping accumulation
# Train:   7%|▋         | 46/641 [00:43<01:58,  5.01it/s]2026-06-13 09:49:12 | WARNING  | model_3 | Sup step 46: non-finite loss nan, skipping accumulation
# Train:   7%|▋         | 47/641 [00:43<01:57,  5.04it/s]2026-06-13 09:49:13 | WARNING  | model_3 | Sup step 47: non-finite loss nan, skipping accumulation
# Train:   8%|▊         | 49/641 [00:44<01:57,  5.05it/s]2026-06-13 09:49:13 | WARNING  | model_3 | Sup step 49: non-finite loss nan, skipping accumulation
# Train:   8%|▊         | 53/641 [00:45<01:54,  5.15it/s]2026-06-13 09:49:14 | WARNING  | model_3 | Sup step 53: non-finite loss nan, skipping accumulation
# Train:   8%|▊         | 54/641 [00:45<01:55,  5.09it/s]2026-06-13 09:49:14 | WARNING  | model_3 | Sup step 54: non-finite loss nan, skipping accumulation
# Train:   9%|▊         | 55/641 [00:45<01:55,  5.07it/s]2026-06-13 09:49:14 | WARNING  | model_3 | Sup step 55: non-finite loss nan, skipping accumulation
# Train:   9%|▊         | 56/641 [00:45<01:57,  4.99it/s]2026-06-13 09:49:14 | WARNING  | model_3 | Sup step 56: non-finite loss nan, skipping accumulation
# Train:   9%|▉         | 57/641 [00:45<01:55,  5.06it/s]2026-06-13 09:49:15 | WARNING  | model_3 | Sup step 57: non-finite loss nan, skipping accumulation
# Train:   9%|▉         | 60/641 [00:46<01:55,  5.03it/s]2026-06-13 09:49:15 | WARNING  | model_3 | Sup step 60: non-finite loss nan, skipping accumulation
# Train:  10%|▉         | 62/641 [00:46<01:55,  5.03it/s]2026-06-13 09:49:16 | WARNING  | model_3 | Sup step 62: non-finite loss nan, skipping accumulation
# Train:  10%|▉         | 64/641 [00:47<01:55,  4.99it/s]2026-06-13 09:49:16 | WARNING  | model_3 | Sup step 64: non-finite loss nan, skipping accumulation
# Train:  10%|█         | 65/641 [00:47<01:55,  5.00it/s]2026-06-13 09:49:16 | WARNING  | model_3 | Sup step 65: non-finite loss nan, skipping accumulation
# Train:  11%|█         | 68/641 [00:48<01:54,  5.02it/s]2026-06-13 09:49:17 | WARNING  | model_3 | Sup step 68: non-finite loss nan, skipping accumulation
# Train:  11%|█         | 69/641 [00:48<01:53,  5.03it/s]2026-06-13 09:49:17 | WARNING  | model_3 | Sup step 69: non-finite loss nan, skipping accumulation
# Train:  11%|█         | 70/641 [00:48<01:50,  5.16it/s]2026-06-13 09:49:17 | WARNING  | model_3 | Sup step 70: non-finite loss nan, skipping accumulation
# Train:  11%|█         | 71/641 [00:48<01:46,  5.36it/s]2026-06-13 09:49:17 | WARNING  | model_3 | Sup step 71: non-finite loss nan, skipping accumulation
# Train:  11%|█         | 72/641 [00:48<01:48,  5.26it/s]2026-06-13 09:49:18 | WARNING  | model_3 | Sup step 72: non-finite loss nan, skipping accumulation
# Train:  11%|█▏        | 73/641 [00:48<01:48,  5.26it/s]2026-06-13 09:49:18 | WARNING  | model_3 | Sup step 73: non-finite loss nan, skipping accumulation
# Train:  12%|█▏        | 75/641 [00:49<01:48,  5.19it/s]2026-06-13 09:49:18 | WARNING  | model_3 | Sup step 75: non-finite loss nan, skipping accumulation
# Train:  12%|█▏        | 76/641 [00:49<01:49,  5.14it/s]2026-06-13 09:49:18 | WARNING  | model_3 | Sup step 76: non-finite loss nan, skipping accumulation
# Train:  12%|█▏        | 77/641 [00:49<01:49,  5.13it/s]2026-06-13 09:49:19 | WARNING  | model_3 | Sup step 77: non-finite loss nan, skipping accumulation
# Train:  12%|█▏        | 79/641 [00:50<01:52,  5.00it/s]2026-06-13 09:49:19 | WARNING  | model_3 | Sup step 79: non-finite loss nan, skipping accumulation
# Train:  12%|█▏        | 80/641 [00:50<01:49,  5.13it/s]2026-06-13 09:49:19 | WARNING  | model_3 | Sup step 80: non-finite loss nan, skipping accumulation
# Train:  13%|█▎        | 81/641 [00:50<01:49,  5.13it/s]2026-06-13 09:49:19 | WARNING  | model_3 | Sup step 81: non-finite loss nan, skipping accumulation
# Train:  13%|█▎        | 83/641 [00:50<01:50,  5.05it/s]2026-06-13 09:49:20 | WARNING  | model_3 | Sup step 83: non-finite loss nan, skipping accumulation
# Train:  13%|█▎        | 84/641 [00:51<01:53,  4.91it/s]2026-06-13 09:49:20 | WARNING  | model_3 | Sup step 84: non-finite loss nan, skipping accumulation
# Train:  13%|█▎        | 86/641 [00:51<01:50,  5.04it/s]2026-06-13 09:49:20 | WARNING  | model_3 | Sup step 86: non-finite loss nan, skipping accumulation
# Train:  14%|█▎        | 87/641 [00:51<01:50,  5.02it/s]2026-06-13 09:49:21 | WARNING  | model_3 | Sup step 87: non-finite loss nan, skipping accumulation
# Train:  14%|█▎        | 88/641 [00:51<01:50,  5.01it/s]2026-06-13 09:49:21 | WARNING  | model_3 | Sup step 88: non-finite loss nan, skipping accumulation
# Train:  14%|█▍        | 89/641 [00:52<01:50,  4.99it/s]2026-06-13 09:49:21 | WARNING  | model_3 | Sup step 89: non-finite loss nan, skipping accumulation
# Train:  14%|█▍        | 90/641 [00:52<01:49,  5.05it/s]2026-06-13 09:49:21 | WARNING  | model_3 | Sup step 90: non-finite loss nan, skipping accumulation
# Train:  14%|█▍        | 91/641 [00:52<01:49,  5.04it/s]2026-06-13 09:49:21 | WARNING  | model_3 | Sup step 91: non-finite loss nan, skipping accumulation
# Train:  14%|█▍        | 92/641 [00:52<01:49,  5.01it/s]2026-06-13 09:49:22 | WARNING  | model_3 | Sup step 92: non-finite loss nan, skipping accumulation
# Train:  15%|█▍        | 93/641 [00:52<01:49,  5.03it/s]2026-06-13 09:49:22 | WARNING  | model_3 | Sup step 93: non-finite loss nan, skipping accumulation
# Train:  15%|█▍        | 94/641 [00:53<01:48,  5.06it/s]2026-06-13 09:49:22 | WARNING  | model_3 | Sup step 94: non-finite loss nan, skipping accumulation
# Train:  15%|█▍        | 96/641 [00:53<01:44,  5.22it/s]2026-06-13 09:49:22 | WARNING  | model_3 | Sup step 96: non-finite loss nan, skipping accumulation
# Train:  15%|█▌        | 98/641 [00:53<01:44,  5.19it/s]2026-06-13 09:49:23 | WARNING  | model_3 | Sup step 98: non-finite loss nan, skipping accumulation
# Train:  16%|█▌        | 103/641 [00:54<01:45,  5.09it/s]2026-06-13 09:49:24 | WARNING  | model_3 | Sup step 103: non-finite loss nan, skipping accumulation
# Train:  16%|█▋        | 105/641 [00:55<01:46,  5.04it/s]2026-06-13 09:49:24 | WARNING  | model_3 | Sup step 105: non-finite loss nan, skipping accumulation
# Train:  17%|█▋        | 106/641 [00:55<01:46,  5.03it/s]2026-06-13 09:49:24 | WARNING  | model_3 | Sup step 106: non-finite loss nan, skipping accumulation
# Train:  17%|█▋        | 108/641 [00:55<01:45,  5.05it/s]2026-06-13 09:49:25 | WARNING  | model_3 | Sup step 108: non-finite loss nan, skipping accumulation
# Train:  17%|█▋        | 109/641 [00:56<01:45,  5.02it/s]2026-06-13 09:49:25 | WARNING  | model_3 | Sup step 109: non-finite loss nan, skipping accumulation
# Train:  18%|█▊        | 113/641 [00:56<01:40,  5.25it/s]2026-06-13 09:49:26 | WARNING  | model_3 | Sup step 113: non-finite loss nan, skipping accumulation
# Train:  18%|█▊        | 114/641 [00:57<01:48,  4.85it/s]2026-06-13 09:49:26 | WARNING  | model_3 | Sup step 114: non-finite loss nan, skipping accumulation
# Train:  18%|█▊        | 115/641 [00:57<01:49,  4.82it/s]2026-06-13 09:49:26 | WARNING  | model_3 | Sup step 115: non-finite loss nan, skipping accumulation
# Train:  18%|█▊        | 117/641 [00:57<01:41,  5.18it/s]2026-06-13 09:49:26 | WARNING  | model_3 | Sup step 117: non-finite loss nan, skipping accumulation
# Train:  19%|█▊        | 119/641 [00:58<01:41,  5.12it/s]2026-06-13 09:49:27 | WARNING  | model_3 | Sup step 119: non-finite loss nan, skipping accumulation
# Train:  19%|█▉        | 121/641 [00:58<01:41,  5.13it/s]2026-06-13 09:49:27 | WARNING  | model_3 | Sup step 121: non-finite loss nan, skipping accumulation
# Train:  19%|█▉        | 122/641 [00:58<01:42,  5.07it/s]2026-06-13 09:49:27 | WARNING  | model_3 | Sup step 122: non-finite loss nan, skipping accumulation
# Train:  20%|█▉        | 125/641 [00:59<01:46,  4.83it/s]2026-06-13 09:49:28 | WARNING  | model_3 | Sup step 125: non-finite loss nan, skipping accumulation
# Train:  20%|█▉        | 126/641 [00:59<01:38,  5.20it/s]2026-06-13 09:49:28 | WARNING  | model_3 | Sup step 126: non-finite loss nan, skipping accumulation
# Train:  20%|█▉        | 128/641 [00:59<01:40,  5.12it/s]2026-06-13 09:49:29 | WARNING  | model_3 | Sup step 128: non-finite loss nan, skipping accumulation
# Train:  20%|██        | 129/641 [01:00<01:40,  5.09it/s]2026-06-13 09:49:29 | WARNING  | model_3 | Sup step 129: non-finite loss nan, skipping accumulation
# Train:  20%|██        | 130/641 [01:00<01:40,  5.08it/s]2026-06-13 09:49:29 | WARNING  | model_3 | Sup step 130: non-finite loss nan, skipping accumulation
# Train:  20%|██        | 131/641 [01:00<01:44,  4.90it/s]2026-06-13 09:49:29 | WARNING  | model_3 | Sup step 131: non-finite loss nan, skipping accumulation
# Train:  21%|██        | 132/641 [01:00<01:41,  5.03it/s]2026-06-13 09:49:29 | WARNING  | model_3 | Sup step 132: non-finite loss nan, skipping accumulation
# Train:  21%|██        | 133/641 [01:00<01:41,  5.03it/s]2026-06-13 09:49:30 | WARNING  | model_3 | Sup step 133: non-finite loss nan, skipping accumulation
# Train:  21%|██        | 135/641 [01:01<01:39,  5.07it/s]2026-06-13 09:49:30 | WARNING  | model_3 | Sup step 135: non-finite loss nan, skipping accumulation
# Train:  21%|██        | 136/641 [01:01<01:40,  5.02it/s]2026-06-13 09:49:30 | WARNING  | model_3 | Sup step 136: non-finite loss nan, skipping accumulation
# Train:  22%|██▏       | 138/641 [01:01<01:34,  5.30it/s]2026-06-13 09:49:31 | WARNING  | model_3 | Sup step 138: non-finite loss nan, skipping accumulation
# Train:  22%|██▏       | 139/641 [01:02<01:36,  5.22it/s]2026-06-13 09:49:31 | WARNING  | model_3 | Sup step 139: non-finite loss nan, skipping accumulation
# Train:  22%|██▏       | 141/641 [01:02<01:35,  5.24it/s]2026-06-13 09:49:31 | WARNING  | model_3 | Sup step 141: non-finite loss nan, skipping accumulation
# Train:  22%|██▏       | 142/641 [01:02<01:38,  5.08it/s]2026-06-13 09:49:31 | WARNING  | model_3 | Sup step 142: non-finite loss nan, skipping accumulation
# Train:  22%|██▏       | 144/641 [01:03<01:37,  5.08it/s]2026-06-13 09:49:32 | WARNING  | model_3 | Sup step 144: non-finite loss nan, skipping accumulation
# Train:  23%|██▎       | 145/641 [01:03<01:38,  5.03it/s]2026-06-13 09:49:32 | WARNING  | model_3 | Sup step 145: non-finite loss nan, skipping accumulation
# Train:  23%|██▎       | 148/641 [01:03<01:37,  5.04it/s]2026-06-13 09:49:33 | WARNING  | model_3 | Sup step 148: non-finite loss nan, skipping accumulation
# Train:  23%|██▎       | 149/641 [01:04<01:36,  5.10it/s]2026-06-13 09:49:33 | WARNING  | model_3 | Sup step 149: non-finite loss nan, skipping accumulation
# Train:  24%|██▎       | 152/641 [01:04<01:33,  5.22it/s]2026-06-13 09:49:33 | WARNING  | model_3 | Sup step 152: non-finite loss nan, skipping accumulation
# Train:  24%|██▍       | 155/641 [01:05<01:32,  5.24it/s]2026-06-13 09:49:34 | WARNING  | model_3 | Sup step 155: non-finite loss nan, skipping accumulation
# Train:  24%|██▍       | 157/641 [01:05<01:30,  5.32it/s]2026-06-13 09:49:34 | WARNING  | model_3 | Sup step 157: non-finite loss nan, skipping accumulation
# Train:  25%|██▍       | 158/641 [01:05<01:29,  5.38it/s]2026-06-13 09:49:34 | WARNING  | model_3 | Sup step 158: non-finite loss nan, skipping accumulation
# Train:  25%|██▍       | 159/641 [01:05<01:26,  5.56it/s]2026-06-13 09:49:35 | WARNING  | model_3 | Sup step 159: non-finite loss nan, skipping accumulation
# Train:  25%|██▍       | 160/641 [01:06<01:28,  5.41it/s]2026-06-13 09:49:35 | WARNING  | model_3 | Sup step 160: non-finite loss nan, skipping accumulation
# Train:  25%|██▌       | 163/641 [01:06<01:27,  5.44it/s]2026-06-13 09:49:35 | WARNING  | model_3 | Sup step 163: non-finite loss nan, skipping accumulation
# Train:  26%|██▋       | 169/641 [01:07<01:25,  5.55it/s]2026-06-13 09:49:37 | WARNING  | model_3 | Sup step 169: non-finite loss nan, skipping accumulation
# Train:  27%|██▋       | 170/641 [01:07<01:28,  5.30it/s]2026-06-13 09:49:37 | WARNING  | model_3 | Sup step 170: non-finite loss nan, skipping accumulation
# Train:  27%|██▋       | 171/641 [01:08<01:28,  5.34it/s]2026-06-13 09:49:37 | WARNING  | model_3 | Sup step 171: non-finite loss nan, skipping accumulation
# Train:  27%|██▋       | 174/641 [01:08<01:26,  5.39it/s]2026-06-13 09:49:37 | WARNING  | model_3 | Sup step 174: non-finite loss nan, skipping accumulation
# Train:  27%|██▋       | 175/641 [01:08<01:25,  5.47it/s]2026-06-13 09:49:38 | WARNING  | model_3 | Sup step 175: non-finite loss nan, skipping accumulation
# Train:  27%|██▋       | 176/641 [01:09<01:27,  5.33it/s]2026-06-13 09:49:38 | WARNING  | model_3 | Sup step 176: non-finite loss nan, skipping accumulation
# Train:  28%|██▊       | 177/641 [01:09<01:23,  5.59it/s]2026-06-13 09:49:38 | WARNING  | model_3 | Sup step 177: non-finite loss nan, skipping accumulation
# Train:  28%|██▊       | 179/641 [01:09<01:25,  5.39it/s]2026-06-13 09:49:38 | WARNING  | model_3 | Sup step 179: non-finite loss nan, skipping accumulation
# Train:  28%|██▊       | 181/641 [01:09<01:26,  5.29it/s]2026-06-13 09:49:39 | WARNING  | model_3 | Sup step 181: non-finite loss nan, skipping accumulation
# Train:  29%|██▊       | 184/641 [01:10<01:27,  5.22it/s]2026-06-13 09:49:39 | WARNING  | model_3 | Sup step 184: non-finite loss nan, skipping accumulation
# Train:  29%|██▉       | 185/641 [01:10<01:25,  5.31it/s]2026-06-13 09:49:39 | WARNING  | model_3 | Sup step 185: non-finite loss nan, skipping accumulation
# Train:  29%|██▉       | 186/641 [01:10<01:21,  5.58it/s]2026-06-13 09:49:40 | WARNING  | model_3 | Sup step 186: non-finite loss nan, skipping accumulation
# Train:  29%|██▉       | 187/641 [01:11<01:24,  5.35it/s]2026-06-13 09:49:40 | WARNING  | model_3 | Sup step 187: non-finite loss nan, skipping accumulation
# Train:  29%|██▉       | 188/641 [01:11<01:26,  5.21it/s]2026-06-13 09:49:40 | WARNING  | model_3 | Sup step 188: non-finite loss nan, skipping accumulation
# Train:  29%|██▉       | 189/641 [01:11<01:27,  5.17it/s]2026-06-13 09:49:40 | WARNING  | model_3 | Sup step 189: non-finite loss nan, skipping accumulation
# Train:  30%|██▉       | 190/641 [01:11<01:27,  5.15it/s]2026-06-13 09:49:41 | WARNING  | model_3 | Sup step 190: non-finite loss nan, skipping accumulation
# Train:  30%|██▉       | 191/641 [01:11<01:34,  4.74it/s]2026-06-13 09:49:41 | WARNING  | model_3 | Sup step 191: non-finite loss nan, skipping accumulation
# Train:  30%|██▉       | 192/641 [01:12<01:29,  5.01it/s]2026-06-13 09:49:41 | WARNING  | model_3 | Sup step 192: non-finite loss nan, skipping accumulation
# Train:  30%|███       | 195/641 [01:12<01:27,  5.11it/s]2026-06-13 09:49:41 | WARNING  | model_3 | Sup step 195: non-finite loss nan, skipping accumulation
# Train:  31%|███       | 196/641 [01:12<01:28,  5.03it/s]2026-06-13 09:49:42 | WARNING  | model_3 | Sup step 196: non-finite loss nan, skipping accumulation
# Train:  31%|███       | 198/641 [01:13<01:34,  4.68it/s]2026-06-13 09:49:42 | WARNING  | model_3 | Sup step 198: non-finite loss nan, skipping accumulation
# Train:  31%|███       | 199/641 [01:13<01:31,  4.85it/s]2026-06-13 09:49:42 | WARNING  | model_3 | Sup step 199: non-finite loss nan, skipping accumulation
# Train:  31%|███       | 200/641 [01:13<01:25,  5.15it/s]2026-06-13 09:49:42 | WARNING  | model_3 | Sup step 200: non-finite loss nan, skipping accumulation
# Train:  31%|███▏      | 201/641 [01:13<01:26,  5.11it/s]2026-06-13 09:49:43 | WARNING  | model_3 | Sup step 201: non-finite loss nan, skipping accumulation
# Train:  32%|███▏      | 203/641 [01:14<01:28,  4.93it/s]2026-06-13 09:49:43 | WARNING  | model_3 | Sup step 203: non-finite loss nan, skipping accumulation
# Train:  32%|███▏      | 205/641 [01:14<01:25,  5.09it/s]2026-06-13 09:49:43 | WARNING  | model_3 | Sup step 205: non-finite loss nan, skipping accumulation
# Train:  32%|███▏      | 207/641 [01:15<01:26,  5.04it/s]2026-06-13 09:49:44 | WARNING  | model_3 | Sup step 207: non-finite loss nan, skipping accumulation
# Train:  33%|███▎      | 210/641 [01:15<01:31,  4.72it/s]2026-06-13 09:49:44 | WARNING  | model_3 | Sup step 210: non-finite loss nan, skipping accumulation
# Train:  33%|███▎      | 211/641 [01:15<01:28,  4.87it/s]2026-06-13 09:49:45 | WARNING  | model_3 | Sup step 211: non-finite loss nan, skipping accumulation
# Train:  33%|███▎      | 213/641 [01:16<01:21,  5.23it/s]2026-06-13 09:49:45 | WARNING  | model_3 | Sup step 213: non-finite loss nan, skipping accumulation
# Train:  34%|███▎      | 215/641 [01:16<01:23,  5.10it/s]2026-06-13 09:49:45 | WARNING  | model_3 | Sup step 215: non-finite loss nan, skipping accumulation
# Train:  34%|███▍      | 217/641 [01:17<01:23,  5.06it/s]2026-06-13 09:49:46 | WARNING  | model_3 | Sup step 217: non-finite loss nan, skipping accumulation
# Train:  34%|███▍      | 218/641 [01:17<01:23,  5.07it/s]2026-06-13 09:49:46 | WARNING  | model_3 | Sup step 218: non-finite loss nan, skipping accumulation
# Train:  34%|███▍      | 219/641 [01:17<01:24,  5.01it/s]2026-06-13 09:49:46 | WARNING  | model_3 | Sup step 219: non-finite loss nan, skipping accumulation
# Train:  34%|███▍      | 220/641 [01:17<01:23,  5.04it/s]2026-06-13 09:49:46 | WARNING  | model_3 | Sup step 220: non-finite loss nan, skipping accumulation
# Train:  34%|███▍      | 221/641 [01:17<01:23,  5.04it/s]2026-06-13 09:49:47 | WARNING  | model_3 | Sup step 221: non-finite loss nan, skipping accumulation
# Train:  35%|███▍      | 222/641 [01:18<01:23,  5.03it/s]2026-06-13 09:49:47 | WARNING  | model_3 | Sup step 222: non-finite loss nan, skipping accumulation
# Train:  35%|███▍      | 224/641 [01:18<01:23,  5.02it/s]2026-06-13 09:49:47 | WARNING  | model_3 | Sup step 224: non-finite loss nan, skipping accumulation
# Train:  35%|███▌      | 225/641 [01:18<01:22,  5.05it/s]2026-06-13 09:49:47 | WARNING  | model_3 | Sup step 225: non-finite loss nan, skipping accumulation
# Train:  35%|███▌      | 226/641 [01:18<01:22,  5.01it/s]2026-06-13 09:49:48 | WARNING  | model_3 | Sup step 226: non-finite loss nan, skipping accumulation
# Train:  36%|███▌      | 228/641 [01:19<01:18,  5.23it/s]2026-06-13 09:49:48 | WARNING  | model_3 | Sup step 228: non-finite loss nan, skipping accumulation
# Train:  36%|███▌      | 229/641 [01:19<01:23,  4.91it/s]2026-06-13 09:49:48 | WARNING  | model_3 | Sup step 229: non-finite loss nan, skipping accumulation
# Train:  36%|███▌      | 230/641 [01:19<01:19,  5.14it/s]2026-06-13 09:49:48 | WARNING  | model_3 | Sup step 230: non-finite loss nan, skipping accumulation
# Train:  36%|███▌      | 232/641 [01:20<01:24,  4.86it/s]2026-06-13 09:49:49 | WARNING  | model_3 | Sup step 232: non-finite loss nan, skipping accumulation
# Train:  37%|███▋      | 234/641 [01:20<01:19,  5.11it/s]2026-06-13 09:49:49 | WARNING  | model_3 | Sup step 234: non-finite loss nan, skipping accumulation
# Train:  37%|███▋      | 235/641 [01:20<01:23,  4.87it/s]2026-06-13 09:49:49 | WARNING  | model_3 | Sup step 235: non-finite loss nan, skipping accumulation
# Train:  37%|███▋      | 236/641 [01:20<01:19,  5.09it/s]2026-06-13 09:49:50 | WARNING  | model_3 | Sup step 236: non-finite loss nan, skipping accumulation
# Train:  37%|███▋      | 237/641 [01:21<01:19,  5.06it/s]2026-06-13 09:49:50 | WARNING  | model_3 | Sup step 237: non-finite loss nan, skipping accumulation
# Train:  37%|███▋      | 239/641 [01:21<01:23,  4.83it/s]2026-06-13 09:49:50 | WARNING  | model_3 | Sup step 239: non-finite loss nan, skipping accumulation
# Train:  37%|███▋      | 240/641 [01:21<01:18,  5.09it/s]2026-06-13 09:49:50 | WARNING  | model_3 | Sup step 240: non-finite loss nan, skipping accumulation
# Train:  38%|███▊      | 241/641 [01:21<01:18,  5.07it/s]2026-06-13 09:49:51 | WARNING  | model_3 | Sup step 241: non-finite loss nan, skipping accumulation
# Train:  38%|███▊      | 242/641 [01:22<01:18,  5.06it/s]2026-06-13 09:49:51 | WARNING  | model_3 | Sup step 242: non-finite loss nan, skipping accumulation
# Train:  38%|███▊      | 243/641 [01:22<01:19,  5.01it/s]2026-06-13 09:49:51 | WARNING  | model_3 | Sup step 243: non-finite loss nan, skipping accumulation
# Train:  38%|███▊      | 244/641 [01:22<01:18,  5.03it/s]2026-06-13 09:49:51 | WARNING  | model_3 | Sup step 244: non-finite loss nan, skipping accumulation
# Train:  38%|███▊      | 245/641 [01:22<01:18,  5.04it/s]2026-06-13 09:49:51 | WARNING  | model_3 | Sup step 245: non-finite loss nan, skipping accumulation
# Train:  38%|███▊      | 246/641 [01:22<01:18,  5.04it/s]2026-06-13 09:49:52 | WARNING  | model_3 | Sup step 246: non-finite loss nan, skipping accumulation
# Train:  39%|███▊      | 247/641 [01:23<01:19,  4.98it/s]2026-06-13 09:49:52 | WARNING  | model_3 | Sup step 247: non-finite loss nan, skipping accumulation
# Train:  39%|███▉      | 250/641 [01:23<01:16,  5.10it/s]2026-06-13 09:49:52 | WARNING  | model_3 | Sup step 250: non-finite loss nan, skipping accumulation
# Train:  39%|███▉      | 251/641 [01:23<01:14,  5.22it/s]2026-06-13 09:49:53 | WARNING  | model_3 | Sup step 251: non-finite loss nan, skipping accumulation
# Train:  39%|███▉      | 252/641 [01:24<01:18,  4.98it/s]2026-06-13 09:49:53 | WARNING  | model_3 | Sup step 252: non-finite loss nan, skipping accumulation
# Train:  40%|███▉      | 255/641 [01:24<01:14,  5.17it/s]2026-06-13 09:49:53 | WARNING  | model_3 | Sup step 255: non-finite loss nan, skipping accumulation
# Train:  40%|███▉      | 256/641 [01:24<01:15,  5.09it/s]2026-06-13 09:49:54 | WARNING  | model_3 | Sup step 256: non-finite loss nan, skipping accumulation
# Train:  40%|████      | 257/641 [01:24<01:15,  5.08it/s]2026-06-13 09:49:54 | WARNING  | model_3 | Sup step 257: non-finite loss nan, skipping accumulation
# Train:  40%|████      | 258/641 [01:25<01:15,  5.04it/s]2026-06-13 09:49:54 | WARNING  | model_3 | Sup step 258: non-finite loss nan, skipping accumulation
# Train:  41%|████      | 261/641 [01:25<01:15,  5.06it/s]2026-06-13 09:49:55 | WARNING  | model_3 | Sup step 261: non-finite loss nan, skipping accumulation
# Train:  41%|████      | 262/641 [01:25<01:15,  4.99it/s]2026-06-13 09:49:55 | WARNING  | model_3 | Sup step 262: non-finite loss nan, skipping accumulation
# Train:  41%|████      | 263/641 [01:26<01:15,  5.02it/s]2026-06-13 09:49:55 | WARNING  | model_3 | Sup step 263: non-finite loss nan, skipping accumulation
# Train:  41%|████      | 264/641 [01:26<01:14,  5.04it/s]2026-06-13 09:49:55 | WARNING  | model_3 | Sup step 264: non-finite loss nan, skipping accumulation
# Train:  41%|████▏     | 266/641 [01:26<01:10,  5.29it/s]2026-06-13 09:49:56 | WARNING  | model_3 | Sup step 266: non-finite loss nan, skipping accumulation
# Train:  42%|████▏     | 267/641 [01:26<01:12,  5.19it/s]2026-06-13 09:49:56 | WARNING  | model_3 | Sup step 267: non-finite loss nan, skipping accumulation
# Train:  42%|████▏     | 268/641 [01:27<01:13,  5.06it/s]2026-06-13 09:49:56 | WARNING  | model_3 | Sup step 268: non-finite loss nan, skipping accumulation
# Train:  42%|████▏     | 269/641 [01:27<01:12,  5.11it/s]2026-06-13 09:49:56 | WARNING  | model_3 | Sup step 269: non-finite loss nan, skipping accumulation
# Train:  42%|████▏     | 270/641 [01:27<01:12,  5.08it/s]2026-06-13 09:49:56 | WARNING  | model_3 | Sup step 270: non-finite loss nan, skipping accumulation
# Train:  42%|████▏     | 271/641 [01:27<01:10,  5.23it/s]2026-06-13 09:49:56 | WARNING  | model_3 | Sup step 271: non-finite loss nan, skipping accumulation
# Train:  43%|████▎     | 274/641 [01:28<01:09,  5.27it/s]2026-06-13 09:49:57 | WARNING  | model_3 | Sup step 274: non-finite loss nan, skipping accumulation
# Train:  43%|████▎     | 275/641 [01:28<01:10,  5.18it/s]2026-06-13 09:49:57 | WARNING  | model_3 | Sup step 275: non-finite loss nan, skipping accumulation
# Train:  44%|████▎     | 279/641 [01:29<01:11,  5.08it/s]2026-06-13 09:49:58 | WARNING  | model_3 | Sup step 279: non-finite loss nan, skipping accumulation
# Train:  44%|████▎     | 280/641 [01:29<01:11,  5.03it/s]2026-06-13 09:49:58 | WARNING  | model_3 | Sup step 280: non-finite loss nan, skipping accumulation
# Train:  44%|████▍     | 285/641 [01:30<01:10,  5.03it/s]2026-06-13 09:49:59 | WARNING  | model_3 | Sup step 285: non-finite loss nan, skipping accumulation
# Train:  45%|████▍     | 286/641 [01:30<01:11,  5.00it/s]2026-06-13 09:49:59 | WARNING  | model_3 | Sup step 286: non-finite loss nan, skipping accumulation
# Train:  45%|████▌     | 289/641 [01:31<01:10,  5.02it/s]2026-06-13 09:50:00 | WARNING  | model_3 | Sup step 289: non-finite loss nan, skipping accumulation
# Train:  45%|████▌     | 290/641 [01:31<01:07,  5.21it/s]2026-06-13 09:50:00 | WARNING  | model_3 | Sup step 290: non-finite loss nan, skipping accumulation
# Train:  45%|████▌     | 291/641 [01:31<01:06,  5.23it/s]2026-06-13 09:50:00 | WARNING  | model_3 | Sup step 291: non-finite loss nan, skipping accumulation
# Train:  46%|████▌     | 292/641 [01:31<01:09,  5.05it/s]2026-06-13 09:50:01 | WARNING  | model_3 | Sup step 292: non-finite loss nan, skipping accumulation
# Train:  46%|████▌     | 293/641 [01:32<01:08,  5.09it/s]2026-06-13 09:50:01 | WARNING  | model_3 | Sup step 293: non-finite loss nan, skipping accumulation
# Train:  46%|████▌     | 294/641 [01:32<01:08,  5.08it/s]2026-06-13 09:50:01 | WARNING  | model_3 | Sup step 294: non-finite loss nan, skipping accumulation
# Train:  46%|████▋     | 297/641 [01:32<01:07,  5.09it/s]2026-06-13 09:50:02 | WARNING  | model_3 | Sup step 297: non-finite loss nan, skipping accumulation
# Train:  46%|████▋     | 298/641 [01:33<01:07,  5.10it/s]2026-06-13 09:50:02 | WARNING  | model_3 | Sup step 298: non-finite loss nan, skipping accumulation
# Train:  47%|████▋     | 299/641 [01:33<01:07,  5.06it/s]2026-06-13 09:50:02 | WARNING  | model_3 | Sup step 299: non-finite loss nan, skipping accumulation
# Train:  47%|████▋     | 301/641 [01:33<01:07,  5.03it/s]2026-06-13 09:50:02 | WARNING  | model_3 | Sup step 301: non-finite loss nan, skipping accumulation
# Train:  47%|████▋     | 302/641 [01:33<01:06,  5.11it/s]2026-06-13 09:50:03 | WARNING  | model_3 | Sup step 302: non-finite loss nan, skipping accumulation
# Train:  47%|████▋     | 303/641 [01:34<01:09,  4.85it/s]2026-06-13 09:50:03 | WARNING  | model_3 | Sup step 303: non-finite loss nan, skipping accumulation
# Train:  48%|████▊     | 305/641 [01:34<01:06,  5.08it/s]2026-06-13 09:50:03 | WARNING  | model_3 | Sup step 305: non-finite loss nan, skipping accumulation
# Train:  48%|████▊     | 306/641 [01:34<01:06,  5.01it/s]2026-06-13 09:50:03 | WARNING  | model_3 | Sup step 306: non-finite loss nan, skipping accumulation
# Train:  48%|████▊     | 307/641 [01:34<01:06,  5.04it/s]2026-06-13 09:50:04 | WARNING  | model_3 | Sup step 307: non-finite loss nan, skipping accumulation
# Train:  48%|████▊     | 308/641 [01:35<01:06,  5.03it/s]2026-06-13 09:50:04 | WARNING  | model_3 | Sup step 308: non-finite loss nan, skipping accumulation
# Train:  48%|████▊     | 310/641 [01:35<01:05,  5.08it/s]2026-06-13 09:50:04 | WARNING  | model_3 | Sup step 310: non-finite loss nan, skipping accumulation
# Train:  49%|████▊     | 311/641 [01:35<01:06,  4.98it/s]2026-06-13 09:50:04 | WARNING  | model_3 | Sup step 311: non-finite loss nan, skipping accumulation
# Train:  49%|████▉     | 313/641 [01:36<01:02,  5.28it/s]2026-06-13 09:50:05 | WARNING  | model_3 | Sup step 313: non-finite loss nan, skipping accumulation
# Train:  49%|████▉     | 314/641 [01:36<01:01,  5.32it/s]2026-06-13 09:50:05 | WARNING  | model_3 | Sup step 314: non-finite loss nan, skipping accumulation
# Train:  49%|████▉     | 316/641 [01:36<01:02,  5.24it/s]2026-06-13 09:50:05 | WARNING  | model_3 | Sup step 316: non-finite loss nan, skipping accumulation
# Train:  50%|████▉     | 318/641 [01:36<01:03,  5.12it/s]2026-06-13 09:50:06 | WARNING  | model_3 | Sup step 318: non-finite loss nan, skipping accumulation
# Train:  50%|████▉     | 319/641 [01:37<01:03,  5.06it/s]2026-06-13 09:50:06 | WARNING  | model_3 | Sup step 319: non-finite loss nan, skipping accumulation
# Train:  50%|█████     | 322/641 [01:37<01:02,  5.08it/s]2026-06-13 09:50:07 | WARNING  | model_3 | Sup step 322: non-finite loss nan, skipping accumulation
# Train:  50%|█████     | 323/641 [01:37<01:01,  5.15it/s]2026-06-13 09:50:07 | WARNING  | model_3 | Sup step 323: non-finite loss nan, skipping accumulation
# Train:  51%|█████     | 324/641 [01:38<01:01,  5.15it/s]2026-06-13 09:50:07 | WARNING  | model_3 | Sup step 324: non-finite loss nan, skipping accumulation
# Train:  51%|█████     | 326/641 [01:38<01:01,  5.08it/s]2026-06-13 09:50:07 | WARNING  | model_3 | Sup step 326: non-finite loss nan, skipping accumulation
# Train:  51%|█████     | 327/641 [01:38<01:06,  4.75it/s]2026-06-13 09:50:08 | WARNING  | model_3 | Sup step 327: non-finite loss nan, skipping accumulation
# Train:  51%|█████▏    | 329/641 [01:39<01:03,  4.95it/s]2026-06-13 09:50:08 | WARNING  | model_3 | Sup step 329: non-finite loss nan, skipping accumulation
# Train:  51%|█████▏    | 330/641 [01:39<01:01,  5.10it/s]2026-06-13 09:50:08 | WARNING  | model_3 | Sup step 330: non-finite loss nan, skipping accumulation
# Train:  52%|█████▏    | 331/641 [01:39<01:00,  5.10it/s]2026-06-13 09:50:08 | WARNING  | model_3 | Sup step 331: non-finite loss nan, skipping accumulation
# Train:  52%|█████▏    | 332/641 [01:39<00:59,  5.15it/s]2026-06-13 09:50:09 | WARNING  | model_3 | Sup step 332: non-finite loss nan, skipping accumulation
# Train:  52%|█████▏    | 333/641 [01:39<01:00,  5.10it/s]2026-06-13 09:50:09 | WARNING  | model_3 | Sup step 333: non-finite loss nan, skipping accumulation
# Train:  52%|█████▏    | 335/641 [01:40<01:00,  5.04it/s]2026-06-13 09:50:09 | WARNING  | model_3 | Sup step 335: non-finite loss nan, skipping accumulation
# Train:  52%|█████▏    | 336/641 [01:40<00:59,  5.09it/s]2026-06-13 09:50:09 | WARNING  | model_3 | Sup step 336: non-finite loss nan, skipping accumulation
# Train:  53%|█████▎    | 337/641 [01:40<01:00,  5.00it/s]2026-06-13 09:50:10 | WARNING  | model_3 | Sup step 337: non-finite loss nan, skipping accumulation
# Train:  53%|█████▎    | 338/641 [01:40<01:00,  5.01it/s]2026-06-13 09:50:10 | WARNING  | model_3 | Sup step 338: non-finite loss nan, skipping accumulation
# Train:  53%|█████▎    | 340/641 [01:41<00:56,  5.29it/s]2026-06-13 09:50:10 | WARNING  | model_3 | Sup step 340: non-finite loss nan, skipping accumulation
# Train:  53%|█████▎    | 342/641 [01:41<00:56,  5.31it/s]2026-06-13 09:50:10 | WARNING  | model_3 | Sup step 342: non-finite loss nan, skipping accumulation
# Train:  54%|█████▎    | 343/641 [01:41<00:54,  5.45it/s]2026-06-13 09:50:11 | WARNING  | model_3 | Sup step 343: non-finite loss nan, skipping accumulation
# Train:  54%|█████▎    | 344/641 [01:42<00:55,  5.31it/s]2026-06-13 09:50:11 | WARNING  | model_3 | Sup step 344: non-finite loss nan, skipping accumulation
# Train:  54%|█████▍    | 347/641 [01:42<00:55,  5.28it/s]2026-06-13 09:50:11 | WARNING  | model_3 | Sup step 347: non-finite loss nan, skipping accumulation
# Train:  54%|█████▍    | 348/641 [01:42<00:55,  5.26it/s]2026-06-13 09:50:12 | WARNING  | model_3 | Sup step 348: non-finite loss nan, skipping accumulation
# Train:  54%|█████▍    | 349/641 [01:42<00:56,  5.19it/s]2026-06-13 09:50:12 | WARNING  | model_3 | Sup step 349: non-finite loss nan, skipping accumulation
# Train:  55%|█████▍    | 350/641 [01:43<00:53,  5.44it/s]2026-06-13 09:50:12 | WARNING  | model_3 | Sup step 350: non-finite loss nan, skipping accumulation
# Train:  55%|█████▍    | 352/641 [01:43<00:55,  5.23it/s]2026-06-13 09:50:12 | WARNING  | model_3 | Sup step 352: non-finite loss nan, skipping accumulation
# Train:  55%|█████▌    | 353/641 [01:43<00:50,  5.67it/s]2026-06-13 09:50:12 | WARNING  | model_3 | Sup step 353: non-finite loss nan, skipping accumulation
# Train:  55%|█████▌    | 354/641 [01:43<00:52,  5.42it/s]2026-06-13 09:50:13 | WARNING  | model_3 | Sup step 354: non-finite loss nan, skipping accumulation
# Train:  55%|█████▌    | 355/641 [01:44<00:54,  5.27it/s]2026-06-13 09:50:13 | WARNING  | model_3 | Sup step 355: non-finite loss nan, skipping accumulation
# Train:  56%|█████▌    | 356/641 [01:44<00:53,  5.30it/s]2026-06-13 09:50:13 | WARNING  | model_3 | Sup step 356: non-finite loss nan, skipping accumulation
# Train:  56%|█████▌    | 358/641 [01:44<00:52,  5.37it/s]2026-06-13 09:50:13 | WARNING  | model_3 | Sup step 358: non-finite loss nan, skipping accumulation
# Train:  56%|█████▌    | 359/641 [01:44<00:52,  5.42it/s]2026-06-13 09:50:14 | WARNING  | model_3 | Sup step 359: non-finite loss nan, skipping accumulation
# Train:  56%|█████▌    | 360/641 [01:44<00:49,  5.63it/s]2026-06-13 09:50:14 | WARNING  | model_3 | Sup step 360: non-finite loss nan, skipping accumulation
# Train:  56%|█████▋    | 362/641 [01:45<00:52,  5.32it/s]2026-06-13 09:50:14 | WARNING  | model_3 | Sup step 362: non-finite loss nan, skipping accumulation
# Train:  57%|█████▋    | 363/641 [01:45<00:51,  5.35it/s]2026-06-13 09:50:14 | WARNING  | model_3 | Sup step 363: non-finite loss nan, skipping accumulation
# Train:  57%|█████▋    | 364/641 [01:45<00:51,  5.42it/s]2026-06-13 09:50:15 | WARNING  | model_3 | Sup step 364: non-finite loss nan, skipping accumulation
# Train:  57%|█████▋    | 365/641 [01:45<00:52,  5.29it/s]2026-06-13 09:50:15 | WARNING  | model_3 | Sup step 365: non-finite loss nan, skipping accumulation
# Train:  57%|█████▋    | 368/641 [01:46<00:50,  5.36it/s]2026-06-13 09:50:15 | WARNING  | model_3 | Sup step 368: non-finite loss nan, skipping accumulation
# Train:  58%|█████▊    | 369/641 [01:46<00:50,  5.35it/s]2026-06-13 09:50:15 | WARNING  | model_3 | Sup step 369: non-finite loss nan, skipping accumulation
# Train:  58%|█████▊    | 370/641 [01:46<00:49,  5.49it/s]2026-06-13 09:50:16 | WARNING  | model_3 | Sup step 370: non-finite loss nan, skipping accumulation
# Train:  58%|█████▊    | 371/641 [01:47<00:50,  5.31it/s]2026-06-13 09:50:16 | WARNING  | model_3 | Sup step 371: non-finite loss nan, skipping accumulation
# Train:  58%|█████▊    | 372/641 [01:47<00:51,  5.22it/s]2026-06-13 09:50:16 | WARNING  | model_3 | Sup step 372: non-finite loss nan, skipping accumulation
# Train:  58%|█████▊    | 374/641 [01:47<00:50,  5.26it/s]2026-06-13 09:50:16 | WARNING  | model_3 | Sup step 374: non-finite loss nan, skipping accumulation
# Train:  59%|█████▊    | 376/641 [01:48<00:50,  5.21it/s]2026-06-13 09:50:17 | WARNING  | model_3 | Sup step 376: non-finite loss nan, skipping accumulation
# Train:  59%|█████▉    | 378/641 [01:48<00:50,  5.22it/s]2026-06-13 09:50:17 | WARNING  | model_3 | Sup step 378: non-finite loss nan, skipping accumulation
# Train:  59%|█████▉    | 381/641 [01:48<00:50,  5.10it/s]2026-06-13 09:50:18 | WARNING  | model_3 | Sup step 381: non-finite loss nan, skipping accumulation
# Train:  60%|█████▉    | 382/641 [01:49<00:51,  5.05it/s]2026-06-13 09:50:18 | WARNING  | model_3 | Sup step 382: non-finite loss nan, skipping accumulation
# Train:  60%|█████▉    | 383/641 [01:49<00:51,  5.04it/s]2026-06-13 09:50:18 | WARNING  | model_3 | Sup step 383: non-finite loss nan, skipping accumulation
# Train:  60%|██████    | 385/641 [01:49<00:50,  5.04it/s]2026-06-13 09:50:19 | WARNING  | model_3 | Sup step 385: non-finite loss nan, skipping accumulation
# Train:  60%|██████    | 386/641 [01:49<00:51,  4.97it/s]2026-06-13 09:50:19 | WARNING  | model_3 | Sup step 386: non-finite loss nan, skipping accumulation
# Train:  60%|██████    | 387/641 [01:50<00:50,  4.99it/s]2026-06-13 09:50:19 | WARNING  | model_3 | Sup step 387: non-finite loss nan, skipping accumulation
# Train:  61%|██████    | 391/641 [01:50<00:48,  5.20it/s]2026-06-13 09:50:20 | WARNING  | model_3 | Sup step 391: non-finite loss nan, skipping accumulation
# Train:  61%|██████▏   | 394/641 [01:51<00:48,  5.11it/s]2026-06-13 09:50:20 | WARNING  | model_3 | Sup step 394: non-finite loss nan, skipping accumulation
# Train:  62%|██████▏   | 395/641 [01:51<00:48,  5.07it/s]2026-06-13 09:50:21 | WARNING  | model_3 | Sup step 395: non-finite loss nan, skipping accumulation
# Train:  62%|██████▏   | 398/641 [01:52<00:47,  5.08it/s]2026-06-13 09:50:21 | WARNING  | model_3 | Sup step 398: non-finite loss nan, skipping accumulation
# Train:  62%|██████▏   | 399/641 [01:52<00:48,  5.03it/s]2026-06-13 09:50:21 | WARNING  | model_3 | Sup step 399: non-finite loss nan, skipping accumulation
# Train:  63%|██████▎   | 401/641 [01:52<00:46,  5.12it/s]2026-06-13 09:50:22 | WARNING  | model_3 | Sup step 401: non-finite loss nan, skipping accumulation
# Train:  63%|██████▎   | 402/641 [01:53<00:48,  4.97it/s]2026-06-13 09:50:22 | WARNING  | model_3 | Sup step 402: non-finite loss nan, skipping accumulation
# Train:  63%|██████▎   | 403/641 [01:53<00:47,  5.03it/s]2026-06-13 09:50:22 | WARNING  | model_3 | Sup step 403: non-finite loss nan, skipping accumulation
# Train:  63%|██████▎   | 405/641 [01:53<00:44,  5.27it/s]2026-06-13 09:50:22 | WARNING  | model_3 | Sup step 405: non-finite loss nan, skipping accumulation
# Train:  63%|██████▎   | 406/641 [01:53<00:45,  5.17it/s]2026-06-13 09:50:23 | WARNING  | model_3 | Sup step 406: non-finite loss nan, skipping accumulation
# Train:  63%|██████▎   | 407/641 [01:54<00:45,  5.17it/s]2026-06-13 09:50:23 | WARNING  | model_3 | Sup step 407: non-finite loss nan, skipping accumulation
# Train:  64%|██████▎   | 408/641 [01:54<00:45,  5.14it/s]2026-06-13 09:50:23 | WARNING  | model_3 | Sup step 408: non-finite loss nan, skipping accumulation
# Train:  64%|██████▍   | 409/641 [01:54<00:49,  4.72it/s]2026-06-13 09:50:23 | WARNING  | model_3 | Sup step 409: non-finite loss nan, skipping accumulation
# Train:  64%|██████▍   | 410/641 [01:54<00:44,  5.15it/s]2026-06-13 09:50:23 | WARNING  | model_3 | Sup step 410: non-finite loss nan, skipping accumulation
# Train:  64%|██████▍   | 411/641 [01:54<00:45,  5.09it/s]2026-06-13 09:50:24 | WARNING  | model_3 | Sup step 411: non-finite loss nan, skipping accumulation
# Train:  65%|██████▍   | 414/641 [01:55<00:44,  5.09it/s]2026-06-13 09:50:24 | WARNING  | model_3 | Sup step 414: non-finite loss nan, skipping accumulation
# Train:  65%|██████▍   | 415/641 [01:55<00:44,  5.05it/s]2026-06-13 09:50:24 | WARNING  | model_3 | Sup step 415: non-finite loss nan, skipping accumulation
# Train:  65%|██████▌   | 418/641 [01:56<00:47,  4.73it/s]2026-06-13 09:50:25 | WARNING  | model_3 | Sup step 418: non-finite loss nan, skipping accumulation
# Train:  65%|██████▌   | 419/641 [01:56<00:43,  5.11it/s]2026-06-13 09:50:25 | WARNING  | model_3 | Sup step 419: non-finite loss nan, skipping accumulation
# Train:  66%|██████▌   | 420/641 [01:56<00:43,  5.09it/s]2026-06-13 09:50:25 | WARNING  | model_3 | Sup step 420: non-finite loss nan, skipping accumulation
# Train:  66%|██████▌   | 423/641 [01:57<00:43,  5.04it/s]2026-06-13 09:50:26 | WARNING  | model_3 | Sup step 423: non-finite loss nan, skipping accumulation
# Train:  66%|██████▌   | 424/641 [01:57<00:45,  4.75it/s]2026-06-13 09:50:26 | WARNING  | model_3 | Sup step 424: non-finite loss nan, skipping accumulation
# Train:  66%|██████▋   | 425/641 [01:57<00:42,  5.11it/s]2026-06-13 09:50:26 | WARNING  | model_3 | Sup step 425: non-finite loss nan, skipping accumulation
# Train:  66%|██████▋   | 426/641 [01:57<00:42,  5.06it/s]2026-06-13 09:50:27 | WARNING  | model_3 | Sup step 426: non-finite loss nan, skipping accumulation
# ...
# Train:  89%|████████▉ | 571/641 [02:26<00:13,  5.07it/s]2026-06-13 09:50:55 | WARNING  | model_3 | Sup step 571: non-finite loss nan, skipping accumulation
# Train:  89%|████████▉ | 572/641 [02:26<00:13,  5.04it/s]2026-06-13 09:50:55 | WARNING  | model_3 | Sup step 572: non-finite loss nan, skipping accumulation
# Train:  89%|████████▉ | 573/641 [02:26<00:13,  5.02it/s]2026-06-13 09:50:55 | WARNING  | model_3 | Sup step 573: non-finite loss nan, skipping accumulation
# Train:  90%|████████▉ | 574/641 [02:26<00:13,  5.06it/s]2026-06-13 09:50:55 | WARNING  | model_3 | Sup step 574: non-finite loss nan, skipping accumulation
# Train:  90%|████████▉ | 575/641 [02:26<00:13,  4.97it/s]2026-06-13 09:50:56 | WARNING  | model_3 | Sup step 575: non-finite loss nan, skipping accumulation
# Train:  90%|████████▉ | 576/641 [02:27<00:12,  5.01it/s]2026-06-13 09:50:56 | WARNING  | model_3 | Sup step 576: non-finite loss nan, skipping accumulation
# Train:  90%|█████████ | 577/641 [02:27<00:12,  5.16it/s]2026-06-13 09:50:56 | WARNING  | model_3 | Sup step 577: non-finite loss nan, skipping accumulation
# Train:  90%|█████████ | 578/641 [02:27<00:12,  4.97it/s]2026-06-13 09:50:56 | WARNING  | model_3 | Sup step 578: non-finite loss nan, skipping accumulation
# Train:  90%|█████████ | 579/641 [02:27<00:12,  5.00it/s]2026-06-13 09:50:56 | WARNING  | model_3 | Sup step 579: non-finite loss nan, skipping accumulation
# Train:  91%|█████████ | 584/641 [02:28<00:11,  5.07it/s]2026-06-13 09:50:57 | WARNING  | model_3 | Sup step 584: non-finite loss nan, skipping accumulation
# Train:  91%|█████████▏| 585/641 [02:28<00:11,  5.08it/s]2026-06-13 09:50:58 | WARNING  | model_3 | Sup step 585: non-finite loss nan, skipping accumulation
# Train:  91%|█████████▏| 586/641 [02:29<00:10,  5.10it/s]2026-06-13 09:50:58 | WARNING  | model_3 | Sup step 586: non-finite loss nan, skipping accumulation
# Train:  92%|█████████▏| 587/641 [02:29<00:10,  5.00it/s]2026-06-13 09:50:58 | WARNING  | model_3 | Sup step 587: non-finite loss nan, skipping accumulation
# Train:  92%|█████████▏| 588/641 [02:29<00:10,  4.95it/s]2026-06-13 09:50:58 | WARNING  | model_3 | Sup step 588: non-finite loss nan, skipping accumulation
# Train:  92%|█████████▏| 589/641 [02:29<00:10,  5.00it/s]2026-06-13 09:50:58 | WARNING  | model_3 | Sup step 589: non-finite loss nan, skipping accumulation
# Train:  92%|█████████▏| 590/641 [02:29<00:10,  4.97it/s]2026-06-13 09:50:59 | WARNING  | model_3 | Sup step 590: non-finite loss nan, skipping accumulation
# Train:  92%|█████████▏| 591/641 [02:30<00:10,  4.98it/s]2026-06-13 09:50:59 | WARNING  | model_3 | Sup step 591: non-finite loss nan, skipping accumulation
# Train:  92%|█████████▏| 592/641 [02:30<00:09,  5.02it/s]2026-06-13 09:50:59 | WARNING  | model_3 | Sup step 592: non-finite loss nan, skipping accumulation
# Train:  93%|█████████▎| 593/641 [02:30<00:09,  5.06it/s]2026-06-13 09:50:59 | WARNING  | model_3 | Sup step 593: non-finite loss nan, skipping accumulation
# Train:  93%|█████████▎| 594/641 [02:30<00:09,  4.99it/s]2026-06-13 09:50:59 | WARNING  | model_3 | Sup step 594: non-finite loss nan, skipping accumulation
# Train:  93%|█████████▎| 595/641 [02:30<00:09,  5.06it/s]2026-06-13 09:51:00 | WARNING  | model_3 | Sup step 595: non-finite loss nan, skipping accumulation
# Train:  93%|█████████▎| 596/641 [02:31<00:08,  5.16it/s]2026-06-13 09:51:00 | WARNING  | model_3 | Sup step 596: non-finite loss nan, skipping accumulation
# Train:  93%|█████████▎| 597/641 [02:31<00:08,  5.24it/s]2026-06-13 09:51:00 | WARNING  | model_3 | Sup step 597: non-finite loss nan, skipping accumulation
# Train:  93%|█████████▎| 598/641 [02:31<00:08,  5.31it/s]2026-06-13 09:51:00 | WARNING  | model_3 | Sup step 598: non-finite loss nan, skipping accumulation
# Train:  93%|█████████▎| 599/641 [02:31<00:08,  5.19it/s]2026-06-13 09:51:00 | WARNING  | model_3 | Sup step 599: non-finite loss nan, skipping accumulation
# Train:  94%|█████████▎| 600/641 [02:31<00:07,  5.13it/s]2026-06-13 09:51:01 | WARNING  | model_3 | Sup step 600: non-finite loss nan, skipping accumulation
# Train:  94%|█████████▍| 601/641 [02:31<00:07,  5.10it/s]2026-06-13 09:51:01 | WARNING  | model_3 | Sup step 601: non-finite loss nan, skipping accumulation
# Train:  94%|█████████▍| 602/641 [02:32<00:07,  5.11it/s]2026-06-13 09:51:01 | WARNING  | model_3 | Sup step 602: non-finite loss nan, skipping accumulation
# Train:  94%|█████████▍| 603/641 [02:32<00:07,  5.03it/s]2026-06-13 09:51:01 | WARNING  | model_3 | Sup step 603: non-finite loss nan, skipping accumulation
# Train:  94%|█████████▍| 604/641 [02:32<00:07,  5.04it/s]2026-06-13 09:51:01 | WARNING  | model_3 | Sup step 604: non-finite loss nan, skipping accumulation
# Train:  94%|█████████▍| 605/641 [02:32<00:07,  5.06it/s]2026-06-13 09:51:02 | WARNING  | model_3 | Sup step 605: non-finite loss nan, skipping accumulation
# Train:  95%|█████████▍| 606/641 [02:32<00:06,  5.03it/s]2026-06-13 09:51:02 | WARNING  | model_3 | Sup step 606: non-finite loss nan, skipping accumulation
# Train:  95%|█████████▍| 607/641 [02:33<00:06,  5.04it/s]2026-06-13 09:51:02 | WARNING  | model_3 | Sup step 607: non-finite loss nan, skipping accumulation
# Train:  95%|█████████▍| 608/641 [02:33<00:06,  5.18it/s]2026-06-13 09:51:02 | WARNING  | model_3 | Sup step 608: non-finite loss nan, skipping accumulation
# Train:  95%|█████████▌| 609/641 [02:33<00:06,  5.23it/s]2026-06-13 09:51:02 | WARNING  | model_3 | Sup step 609: non-finite loss nan, skipping accumulation
# Train:  95%|█████████▌| 610/641 [02:33<00:05,  5.21it/s]2026-06-13 09:51:03 | WARNING  | model_3 | Sup step 610: non-finite loss nan, skipping accumulation
# Train:  95%|█████████▌| 611/641 [02:33<00:05,  5.06it/s]2026-06-13 09:51:03 | WARNING  | model_3 | Sup step 611: non-finite loss nan, skipping accumulation
# Train:  95%|█████████▌| 612/641 [02:34<00:05,  5.12it/s]2026-06-13 09:51:03 | WARNING  | model_3 | Sup step 612: non-finite loss nan, skipping accumulation
# Train:  96%|█████████▌| 613/641 [02:34<00:05,  5.10it/s]2026-06-13 09:51:03 | WARNING  | model_3 | Sup step 613: non-finite loss nan, skipping accumulation
# Train:  96%|█████████▌| 614/641 [02:34<00:05,  4.78it/s]2026-06-13 09:51:03 | WARNING  | model_3 | Sup step 614: non-finite loss nan, skipping accumulation
# Train:  96%|█████████▌| 615/641 [02:34<00:05,  5.03it/s]2026-06-13 09:51:04 | WARNING  | model_3 | Sup step 615: non-finite loss nan, skipping accumulation
# Train:  96%|█████████▌| 616/641 [02:34<00:04,  5.10it/s]2026-06-13 09:51:04 | WARNING  | model_3 | Sup step 616: non-finite loss nan, skipping accumulation
# Train:  96%|█████████▋| 617/641 [02:35<00:04,  5.01it/s]2026-06-13 09:51:04 | WARNING  | model_3 | Sup step 617: non-finite loss nan, skipping accumulation
# Train:  96%|█████████▋| 618/641 [02:35<00:04,  5.04it/s]2026-06-13 09:51:04 | WARNING  | model_3 | Sup step 618: non-finite loss nan, skipping accumulation
# Train:  97%|█████████▋| 619/641 [02:35<00:04,  5.05it/s]2026-06-13 09:51:04 | WARNING  | model_3 | Sup step 619: non-finite loss nan, skipping accumulation
# Train:  97%|█████████▋| 620/641 [02:35<00:04,  5.03it/s]2026-06-13 09:51:05 | WARNING  | model_3 | Sup step 620: non-finite loss nan, skipping accumulation
# Train:  97%|█████████▋| 621/641 [02:35<00:03,  5.06it/s]2026-06-13 09:51:05 | WARNING  | model_3 | Sup step 621: non-finite loss nan, skipping accumulation
# Train:  97%|█████████▋| 622/641 [02:36<00:03,  5.02it/s]2026-06-13 09:51:05 | WARNING  | model_3 | Sup step 622: non-finite loss nan, skipping accumulation
# Train:  97%|█████████▋| 623/641 [02:36<00:03,  4.99it/s]2026-06-13 09:51:05 | WARNING  | model_3 | Sup step 623: non-finite loss nan, skipping accumulation
# Train:  97%|█████████▋| 624/641 [02:36<00:03,  5.02it/s]2026-06-13 09:51:05 | WARNING  | model_3 | Sup step 624: non-finite loss nan, skipping accumulation
# Train:  98%|█████████▊| 625/641 [02:36<00:03,  5.01it/s]2026-06-13 09:51:06 | WARNING  | model_3 | Sup step 625: non-finite loss nan, skipping accumulation
# Train:  98%|█████████▊| 626/641 [02:36<00:02,  5.02it/s]2026-06-13 09:51:06 | WARNING  | model_3 | Sup step 626: non-finite loss nan, skipping accumulation
# Train:  98%|█████████▊| 627/641 [02:37<00:02,  5.03it/s]2026-06-13 09:51:06 | WARNING  | model_3 | Sup step 627: non-finite loss nan, skipping accumulation
# Train:  98%|█████████▊| 628/641 [02:37<00:02,  5.17it/s]2026-06-13 09:51:06 | WARNING  | model_3 | Sup step 628: non-finite loss nan, skipping accumulation
# Train:  98%|█████████▊| 629/641 [02:37<00:02,  4.68it/s]2026-06-13 09:51:06 | WARNING  | model_3 | Sup step 629: non-finite loss nan, skipping accumulation
# Train:  98%|█████████▊| 630/641 [02:37<00:02,  4.98it/s]2026-06-13 09:51:07 | WARNING  | model_3 | Sup step 630: non-finite loss nan, skipping accumulation
# Train:  98%|█████████▊| 631/641 [02:37<00:01,  5.03it/s]2026-06-13 09:51:07 | WARNING  | model_3 | Sup step 631: non-finite loss nan, skipping accumulation
# Train:  99%|█████████▊| 632/641 [02:38<00:01,  5.04it/s]2026-06-13 09:51:07 | WARNING  | model_3 | Sup step 632: non-finite loss nan, skipping accumulation
# Train:  99%|█████████▉| 633/641 [02:38<00:01,  4.78it/s]2026-06-13 09:51:07 | WARNING  | model_3 | Sup step 633: non-finite loss nan, skipping accumulation
# Train:  99%|█████████▉| 634/641 [02:38<00:01,  5.12it/s]2026-06-13 09:51:07 | WARNING  | model_3 | Sup step 634: non-finite loss nan, skipping accumulation
# Train:  99%|█████████▉| 635/641 [02:38<00:01,  5.04it/s]2026-06-13 09:51:08 | WARNING  | model_3 | Sup step 635: non-finite loss nan, skipping accumulation
# Train:  99%|█████████▉| 636/641 [02:38<00:00,  5.07it/s]2026-06-13 09:51:08 | WARNING  | model_3 | Sup step 636: non-finite loss nan, skipping accumulation
# Train:  99%|█████████▉| 637/641 [02:39<00:00,  5.06it/s]2026-06-13 09:51:08 | WARNING  | model_3 | Sup step 637: non-finite loss nan, skipping accumulation
# Train: 100%|█████████▉| 638/641 [02:39<00:00,  5.10it/s]2026-06-13 09:51:08 | WARNING  | model_3 | Sup step 638: non-finite loss nan, skipping accumulation
# Train: 100%|█████████▉| 639/641 [02:39<00:00,  5.10it/s]2026-06-13 09:51:08 | WARNING  | model_3 | Sup step 639: non-finite loss nan, skipping accumulation
# Train: 100%|█████████▉| 640/641 [02:39<00:00,  5.17it/s]2026-06-13 09:51:09 | WARNING  | model_3 | Sup step 640: non-finite loss nan, skipping accumulation
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 104
#     100     log.info("model_3 pipeline complete.")
#     101
#     102
#     103 if __name__ == "__main__":
# --> 104     main()
#
# Cell In[32], line 89, in main()
#      85     n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
#      86     log.info(f"EEGModel parameters: {n_params:,}")
#      87
#      88     # ── 17: Train (Stage 0 MSM + Stage 1 supervised) ─────────────────────────
# ---> 89     model = train_model(model, train_loader, val_loader, class_weights_nh, CONFIG, device)
#      90
#      91     # ── 18: Test evaluation ───────────────────────────────────────────────────
#      92     evaluate_test(model, test_loader, class_weights_nh, CONFIG, device)
#
# Cell In[28], line 61, in train_model(model, train_loader, val_loader, class_weights_nh, config, device)
#      57         train_loss = train_one_epoch(
#      58             model, train_loader, optimizer_sup, amp_scaler,
#      59             class_weights_nh, config, device,
#      60         )
# ---> 61         val_loss, val_metrics = validate(model, val_loader, class_weights_nh, config, device)
#      62         scheduler.step()
#      63         elapsed = time.time() - t0
#      64         log.info(
#
# Cell In[26], line 67, in validate(model, loader, class_weights_nh, config, device)
#      63                    zip(["ioh_5","ioh_10","ioh_15"],[all_ioh5_true,all_ioh10_true,all_ioh15_true])}
#      64     nh_preds    = np.concatenate(all_nh_pred)
#      65     nh_targets  = np.concatenate(all_nh_true)
#      66
# ---> 67     metrics = compute_metrics(ioh_preds, ioh_targets, nh_preds, nh_targets)
#      68     return val_loss, metrics
#
# Cell In[22], line 22, in compute_metrics(ioh_preds, ioh_targets, nh_preds, nh_targets)
#      18         if len(np.unique(t)) < 2:
#      19             metrics[f"auroc_{key}"] = float("nan")
#      20             metrics[f"auprc_{key}"] = float("nan")
#      21         else:
# ---> 22             metrics[f"auroc_{key}"] = float(roc_auc_score(t, p))
#      23             metrics[f"auprc_{key}"] = float(average_precision_score(t, p))
#      24     metrics["nh_balanced_acc"] = float(balanced_accuracy_score(nh_targets, nh_preds))
#      25     metrics["nh_macro_f1"]     = float(f1_score(nh_targets, nh_preds, average="macro", zero_division=0))
#
# File /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:710, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     708 y_type = type_of_target(y_true, input_name="y_true")
#     709 y_true = check_array(y_true, ensure_2d=False, dtype=None)
# --> 710 y_score = check_array(y_score, ensure_2d=False)
#     711 if sample_weight is not None:
#     712     sample_weight = column_or_1d(sample_weight)
#
# File /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1081     raise ValueError(
#    1082         f"Found array with dim {array.ndim},"
#    1083         f" while dim <= 2 is required{context}."
#    1084     )
#    1086 if ensure_all_finite:
# -> 1087     _assert_all_finite(
#    1088         array,
#    1089         input_name=input_name,
#    1090         estimator_name=estimator_name,
#    1091         allow_nan=ensure_all_finite == "allow-nan",
#    1092     )
#    1094 if copy:
#    1095     if _is_numpy_namespace(xp):
#    1096         # only make a copy if `array` and `array_orig` may share memory`
#
# File /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:137, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     134 if first_pass_isfinite:
#     135     return
# --> 137 _assert_all_finite_element_wise(
#     138     X,
#     139     xp=xp,
#     140     allow_nan=allow_nan,
#     141     msg_dtype=msg_dtype,
#     142     estimator_name=estimator_name,
#     143     input_name=input_name,
#     144 )
#
# File /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:186, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     169 if estimator_name and input_name == "X" and has_nan_error:
#     170     # Improve the error message on how to handle missing values in
#     171     # scikit-learn.
#     172     msg_err += (
#     173         f"\n{estimator_name} does not accept missing values"
#     174         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    184         "#estimators-that-handle-nan-values"
#     185     )
# --> 186 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
# Run the full pipeline
main()
